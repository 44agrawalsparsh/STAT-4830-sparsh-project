# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join('..', 'src')))

# %%
import json
from auction_env import AuctionEnv, generate_athletes
from format_roster import format_roster, print_roster
from benchmark_auctions import run_auction
import numpy as np

def generate_random_strategies(specified=None):
    strategies = {}
    if specified is not None:
        for i in range(6):
            strategy_type = specified[i]
            if strategy_type == 'monte_carlo':
                strategies[i] = {'type': 'monte_carlo', 'num_simulations': np.random.randint(25, 50)}
            elif strategy_type == 'flip':
                strategies[i] = {'type': 'flip', 'p': np.random.uniform(0.1, 0.9)}
            elif strategy_type == 'proportional':
                strategies[i] = {'type': 'proportional', 'weight_vector': np.random.dirichlet(np.ones(3), size=1)[0].tolist()}
            elif strategy_type == 'value_above_replacement':
                strategies[i] = {'type': 'value_above_replacement'}
            elif strategy_type == 'always_bid':
                strategies[i] = {'type': 'always_bid'}
        return strategies
    
    for i in range(6):
        strategy_type = np.random.choice(['monte_carlo', 'flip', 'proportional', 'value_above_replacement', 'always_bid'])
        if strategy_type == 'monte_carlo':
            strategies[i] = {'type': 'monte_carlo', 'num_simulations': np.random.randint(50, 150)}
        elif strategy_type == 'flip':
            strategies[i] = {'type': 'flip', 'p': np.random.uniform(0.1, 0.9)}
        elif strategy_type == 'proportional':
            strategies[i] = {'type': 'proportional', 'weight_vector': np.random.dirichlet(np.ones(3), size=1)[0].tolist()}
        elif strategy_type == 'value_above_replacement':
            strategies[i] = {'type': 'value_above_replacement'}
        elif strategy_type == 'always_bid':
            strategies[i] = {'type': 'always_bid'}
    return strategies

def run_and_display_auction(output_file_path, specified=None):
    strategies = generate_random_strategies(specified)
    export_file = 'auction_results.txt'
    run_auction(export_file, strategies)
    
    with open(export_file, 'r') as file:
        lines = file.readlines()
        history = eval(lines[0], {"np": __import__("numpy"), "Athlete": AuctionEnv.Athlete, "Position": AuctionEnv.Position})
        player_scores = json.loads(lines[1])
    
    teams = format_roster(history, strategies, player_scores)
    with open(output_file_path, 'w') as file:
        print_roster(teams, file)

# %%
specified = ['monte_carlo', 'flip', 'proportional', 'value_above_replacement', 'always_bid', 'proportional']
run_and_display_auction('../test_outputs/output1.txt', specified)
# Out:
# Auctioning off:
# Position.FORWARD
# Athlete(mean=176.50825774259636, variance=19.214842386065058, position=Position.FORWARD), Rank: 1
# Athlete(mean=151.62486870993155, variance=42.276085713040544, position=Position.FORWARD), Rank: 2
# Athlete(mean=147.54823533228662, variance=34.77242136512042, position=Position.FORWARD), Rank: 3
# Athlete(mean=125.42009889299914, variance=16.976770550508608, position=Position.FORWARD), Rank: 4
# Athlete(mean=89.22644996105691, variance=10.213864398435403, position=Position.FORWARD), Rank: 5
# Athlete(mean=85.41816322808153, variance=9.462088761568584, position=Position.FORWARD), Rank: 6
# Athlete(mean=83.9970998616156, variance=8.4054921909825, position=Position.FORWARD), Rank: 7
# Athlete(mean=83.04742366692363, variance=25.6040780843219, position=Position.FORWARD), Rank: 8
# Athlete(mean=72.0175865723358, variance=7.213843677983572, position=Position.FORWARD), Rank: 9
# Athlete(mean=69.96581486189879, variance=11.33560368036962, position=Position.FORWARD), Rank: 10
# Athlete(mean=67.0969388981073, variance=6.883631113532101, position=Position.FORWARD), Rank: 11
# Athlete(mean=64.76988935240583, variance=7.119827812485319, position=Position.FORWARD), Rank: 12
# Athlete(mean=64.18133567895315, variance=12.721704958168258, position=Position.FORWARD), Rank: 13
# Athlete(mean=61.1269111053835, variance=7.400685514256459, position=Position.FORWARD), Rank: 14
# Athlete(mean=58.98039567649392, variance=6.25355178264325, position=Position.FORWARD), Rank: 15
# Athlete(mean=57.71741458709776, variance=6.476706179615746, position=Position.FORWARD), Rank: 16
# Athlete(mean=57.20711127811333, variance=8.88441685151178, position=Position.FORWARD), Rank: 17
# Athlete(mean=55.43685086958216, variance=6.554442553135145, position=Position.FORWARD), Rank: 18
# Athlete(mean=51.0113707722143, variance=10.363612210769793, position=Position.FORWARD), Rank: 19
# Athlete(mean=50.96854385686986, variance=6.6964148104711105, position=Position.FORWARD), Rank: 20
# Athlete(mean=50.66428579269578, variance=5.099258642063066, position=Position.FORWARD), Rank: 21
# Athlete(mean=48.98513319060327, variance=5.693584171440211, position=Position.FORWARD), Rank: 22
# Athlete(mean=47.2727346254785, variance=5.790059469371176, position=Position.FORWARD), Rank: 23
# Athlete(mean=46.98402298662357, variance=28.091779295507454, position=Position.FORWARD), Rank: 24
# Athlete(mean=46.560947081385834, variance=5.283446115774057, position=Position.FORWARD), Rank: 25
# Athlete(mean=44.54442850405697, variance=5.050324712312614, position=Position.FORWARD), Rank: 26
# Athlete(mean=40.17551004919885, variance=4.941576670384136, position=Position.FORWARD), Rank: 27
# Athlete(mean=40.13254155762361, variance=7.669747250880668, position=Position.FORWARD), Rank: 28
# Athlete(mean=39.43481325612046, variance=9.793334209344422, position=Position.FORWARD), Rank: 29
# Athlete(mean=36.91342855890723, variance=3.977487167512261, position=Position.FORWARD), Rank: 30
# Athlete(mean=32.229841289040685, variance=7.493789112856014, position=Position.FORWARD), Rank: 31
# Athlete(mean=31.891159848377036, variance=4.370094082397324, position=Position.FORWARD), Rank: 32
# Athlete(mean=28.821799360389633, variance=8.714785591846837, position=Position.FORWARD), Rank: 33
# Athlete(mean=26.049475727368087, variance=3.4364410959132643, position=Position.FORWARD), Rank: 34
# Athlete(mean=25.540669690740945, variance=10.636287129694896, position=Position.FORWARD), Rank: 35
# Athlete(mean=20.879575409418443, variance=8.224726631204899, position=Position.FORWARD), Rank: 36
# Athlete(mean=20.248830654750613, variance=2.0395565443787733, position=Position.FORWARD), Rank: 37
# Athlete(mean=17.50063891996868, variance=3.805148564303403, position=Position.FORWARD), Rank: 38
# Athlete(mean=17.221122417360892, variance=2.236757818195948, position=Position.FORWARD), Rank: 39
# Athlete(mean=12.586299377502097, variance=3.9192207749638626, position=Position.FORWARD), Rank: 40
# Athlete(mean=12.490268847268919, variance=1.5993688010424354, position=Position.FORWARD), Rank: 41
# Athlete(mean=12.418087729293442, variance=11.187077181442922, position=Position.FORWARD), Rank: 42
# Athlete(mean=11.952287468119977, variance=4.064435852433551, position=Position.FORWARD), Rank: 43
# Athlete(mean=11.13885290404092, variance=1.5499702277304563, position=Position.FORWARD), Rank: 44
# Athlete(mean=11.013236991102994, variance=16.957161775964675, position=Position.FORWARD), Rank: 45
# Athlete(mean=10.796916551115704, variance=8.575135826123534, position=Position.FORWARD), Rank: 46
# Athlete(mean=6.917936590764457, variance=0.8651062564990795, position=Position.FORWARD), Rank: 47
# Athlete(mean=5.514691940006127, variance=9.968860474136841, position=Position.FORWARD), Rank: 48
# Position.DEFENSEMAN
# Athlete(mean=38.35212409024792, variance=6.599105574189995, position=Position.DEFENSEMAN), Rank: 1
# Athlete(mean=37.985378754219695, variance=4.472856453207662, position=Position.DEFENSEMAN), Rank: 2
# Athlete(mean=34.70444947640257, variance=22.29104951317752, position=Position.DEFENSEMAN), Rank: 3
# Athlete(mean=33.843899573265375, variance=39.90819554342989, position=Position.DEFENSEMAN), Rank: 4
# Athlete(mean=31.110219625472098, variance=10.530000761618878, position=Position.DEFENSEMAN), Rank: 5
# Athlete(mean=30.479199890146973, variance=4.957581646740579, position=Position.DEFENSEMAN), Rank: 6
# Athlete(mean=28.117240292584746, variance=4.188929550919588, position=Position.DEFENSEMAN), Rank: 7
# Athlete(mean=27.211031584847834, variance=12.070443597430089, position=Position.DEFENSEMAN), Rank: 8
# Athlete(mean=26.53164875931629, variance=4.40574834528052, position=Position.DEFENSEMAN), Rank: 9
# Athlete(mean=24.285242477966662, variance=3.1627581075492257, position=Position.DEFENSEMAN), Rank: 10
# Athlete(mean=23.48637732914707, variance=6.231807865653389, position=Position.DEFENSEMAN), Rank: 11
# Athlete(mean=20.382314155799893, variance=5.66394814546318, position=Position.DEFENSEMAN), Rank: 12
# Athlete(mean=15.598639700413823, variance=4.35267240414526, position=Position.DEFENSEMAN), Rank: 13
# Athlete(mean=14.762018525694087, variance=7.2589279678011795, position=Position.DEFENSEMAN), Rank: 14
# Athlete(mean=14.737809148691156, variance=11.640494225648599, position=Position.DEFENSEMAN), Rank: 15
# Athlete(mean=14.454385301655652, variance=1.51945937955685, position=Position.DEFENSEMAN), Rank: 16
# Athlete(mean=13.974744720033208, variance=4.263272938232657, position=Position.DEFENSEMAN), Rank: 17
# Athlete(mean=12.016015271782159, variance=2.1117399409937754, position=Position.DEFENSEMAN), Rank: 18
# Athlete(mean=10.64419031685548, variance=12.279614241676853, position=Position.DEFENSEMAN), Rank: 19
# Athlete(mean=10.599155044107292, variance=1.4618684187477924, position=Position.DEFENSEMAN), Rank: 20
# Athlete(mean=9.22631703106378, variance=20.324159997974157, position=Position.DEFENSEMAN), Rank: 21
# Athlete(mean=8.721075759471146, variance=1.7543808022719807, position=Position.DEFENSEMAN), Rank: 22
# Athlete(mean=7.636514044205963, variance=10.575020154327948, position=Position.DEFENSEMAN), Rank: 23
# Athlete(mean=4.256861374821428, variance=2.044852174851367, position=Position.DEFENSEMAN), Rank: 24
# Position.GOALIE
# Athlete(mean=128.477853679795, variance=31.06359668379405, position=Position.GOALIE), Rank: 1
# Athlete(mean=99.43981067511069, variance=78.90071194147082, position=Position.GOALIE), Rank: 2
# Athlete(mean=94.33377208917446, variance=141.96653671889322, position=Position.GOALIE), Rank: 3
# Athlete(mean=71.09877578243028, variance=16.88140161785673, position=Position.GOALIE), Rank: 4
# Athlete(mean=64.87307235851402, variance=159.87921498630317, position=Position.GOALIE), Rank: 5
# Athlete(mean=58.76636805701489, variance=66.31392042337065, position=Position.GOALIE), Rank: 6
# Athlete(mean=55.770893261778966, variance=32.74305002635782, position=Position.GOALIE), Rank: 7
# Athlete(mean=34.70590329447202, variance=79.40484086456061, position=Position.GOALIE), Rank: 8
# Athlete(mean=32.82786797945401, variance=16.372026489961378, position=Position.GOALIE), Rank: 9
# Athlete(mean=29.087086127376395, variance=25.727913251928424, position=Position.GOALIE), Rank: 10
# Athlete(mean=28.98077985961011, variance=15.97646569193367, position=Position.GOALIE), Rank: 11
# Athlete(mean=16.709796046121046, variance=23.867061862536115, position=Position.GOALIE), Rank: 12
# {0: {'type': 'monte_carlo', 'num_simulations': 146}, 1: {'type': 'flip', 'p': 0.30348753175037824}, 2: {'type': 'proportional', 'weight_vector': [0.4046273651126828, 0.3179946258248402, 0.27737800906247706]}, 3: {'type': 'value_above_replacement'}, 4: {'type': 'always_bid'}, 5: {'type': 'proportional', 'weight_vector': [0.5519866408631147, 0.09016414166324649, 0.35784921747363885]}}
# {0: {'type': 'monte_carlo', 'num_simulations': 146}, 1: {'type': 'flip', 'p': 0.30348753175037824}, 2: {'type': 'proportional', 'weight_vector': [0.4046273651126828, 0.3179946258248402, 0.27737800906247706]}, 3: {'type': 'value_above_replacement'}, 4: {'type': 'always_bid'}, 5: {'type': 'proportional', 'weight_vector': [0.5519866408631147, 0.09016414166324649, 0.35784921747363885]}}
# {0: {'type': 'monte_carlo', 'num_simulations': 146}, 1: {'type': 'flip', 'p': 0.30348753175037824}, 2: {'type': 'proportional', 'weight_vector': [0.4046273651126828, 0.3179946258248402, 0.27737800906247706]}, 3: {'type': 'value_above_replacement'}, 4: {'type': 'always_bid'}, 5: {'type': 'proportional', 'weight_vector': [0.5519866408631147, 0.09016414166324649, 0.35784921747363885]}}
# {0: {'type': 'monte_carlo', 'num_simulations': 146}, 1: {'type': 'flip', 'p': 0.30348753175037824}, 2: {'type': 'proportional', 'weight_vector': [0.4046273651126828, 0.3179946258248402, 0.27737800906247706]}, 3: {'type': 'value_above_replacement'}, 4: {'type': 'always_bid'}, 5: {'type': 'proportional', 'weight_vector': [0.5519866408631147, 0.09016414166324649, 0.35784921747363885]}}
# {0: {'type': 'monte_carlo', 'num_simulations': 146}, 1: {'type': 'flip', 'p': 0.30348753175037824}, 2: {'type': 'proportional', 'weight_vector': [0.4046273651126828, 0.3179946258248402, 0.27737800906247706]}, 3: {'type': 'value_above_replacement'}, 4: {'type': 'always_bid'}, 5: {'type': 'proportional', 'weight_vector': [0.5519866408631147, 0.09016414166324649, 0.35784921747363885]}}
# {0: {'type': 'monte_carlo', 'num_simulations': 146}, 1: {'type': 'flip', 'p': 0.30348753175037824}, 2: {'type': 'proportional', 'weight_vector': [0.4046273651126828, 0.3179946258248402, 0.27737800906247706]}, 3: {'type': 'value_above_replacement'}, 4: {'type': 'always_bid'}, 5: {'type': 'proportional', 'weight_vector': [0.5519866408631147, 0.09016414166324649, 0.35784921747363885]}}
#
#
#
#
#
#
#
#
#
#
# Player Athlete(mean=58.76636805701489, variance=66.31392042337065, position=Position.GOALIE) is now up for auction.
# SOLD: {'price': 49, 'winner': np.int64(4)}
# Player Athlete(mean=50.66428579269578, variance=5.099258642063066, position=Position.FORWARD) is now up for auction.
# SOLD: {'price': 12, 'winner': np.int64(4)}
# Player Athlete(mean=46.560947081385834, variance=5.283446115774057, position=Position.FORWARD) is now up for auction.
# SOLD: {'price': 11, 'winner': np.int64(4)}
# Player Athlete(mean=7.636514044205963, variance=10.575020154327948, position=Position.DEFENSEMAN) is now up for auction.
# SOLD: {'price': 4, 'winner': np.int64(4)}
# Player Athlete(mean=10.599155044107292, variance=1.4618684187477924, position=Position.DEFENSEMAN) is now up for auction.
# SOLD: {'price': 8, 'winner': np.int64(4)}
# Player Athlete(mean=12.586299377502097, variance=3.9192207749638626, position=Position.FORWARD) is now up for auction.
# SOLD: {'price': 5, 'winner': np.int64(4)}
# Player Athlete(mean=151.62486870993155, variance=42.276085713040544, position=Position.FORWARD) is now up for auction.
# SOLD: {'price': 37, 'winner': np.int64(0)}
# Player Athlete(mean=14.762018525694087, variance=7.2589279678011795, position=Position.DEFENSEMAN) is now up for auction.
# SOLD: {'price': 13, 'winner': np.int64(4)}
# Player Athlete(mean=15.598639700413823, variance=4.35267240414526, position=Position.DEFENSEMAN) is now up for auction.
# SOLD: {'price': 4, 'winner': np.int64(3)}
# Player Athlete(mean=71.09877578243028, variance=16.88140161785673, position=Position.GOALIE) is now up for auction.
# SOLD: {'price': 17, 'winner': np.int64(3)}
# Player Athlete(mean=72.0175865723358, variance=7.213843677983572, position=Position.FORWARD) is now up for auction.
# SOLD: {'price': 10, 'winner': np.int64(3)}
# Player Athlete(mean=50.96854385686986, variance=6.6964148104711105, position=Position.FORWARD) is now up for auction.
# SOLD: {'price': 7, 'winner': np.int64(3)}
# Player Athlete(mean=32.82786797945401, variance=16.372026489961378, position=Position.GOALIE) is now up for auction.
# SOLD: {'price': 8, 'winner': np.int64(3)}
# Player Athlete(mean=40.13254155762361, variance=7.669747250880668, position=Position.FORWARD) is now up for auction.
# SOLD: {'price': 5, 'winner': np.int64(3)}
# Player Athlete(mean=17.50063891996868, variance=3.805148564303403, position=Position.FORWARD) is now up for auction.
# SOLD: {'price': 3, 'winner': np.int64(4)}
# Player Athlete(mean=147.54823533228662, variance=34.77242136512042, position=Position.FORWARD) is now up for auction.
# SOLD: {'price': 33, 'winner': np.int64(0)}
# Player Athlete(mean=32.229841289040685, variance=7.493789112856014, position=Position.FORWARD) is now up for auction.
# SOLD: {'price': 3, 'winner': np.int64(3)}
# Player Athlete(mean=46.98402298662357, variance=28.091779295507454, position=Position.FORWARD) is now up for auction.
# SOLD: {'price': 6, 'winner': np.int64(3)}
# Player Athlete(mean=11.13885290404092, variance=1.5499702277304563, position=Position.FORWARD) is now up for auction.
# SOLD: {'price': 1, 'winner': np.int64(3)}
# Player Athlete(mean=12.016015271782159, variance=2.1117399409937754, position=Position.DEFENSEMAN) is now up for auction.
# SOLD: {'price': 4, 'winner': np.int64(3)}
# Player Athlete(mean=16.709796046121046, variance=23.867061862536115, position=Position.GOALIE) is now up for auction.
# SOLD: {'price': 3, 'winner': np.int64(5)}
# Player Athlete(mean=6.917936590764457, variance=0.8651062564990795, position=Position.FORWARD) is now up for auction.
# SOLD: {'price': 0, 'winner': np.int64(2)}
# Player Athlete(mean=55.770893261778966, variance=32.74305002635782, position=Position.GOALIE) is now up for auction.
# SOLD: {'price': 10, 'winner': np.int64(5)}
# Player Athlete(mean=13.974744720033208, variance=4.263272938232657, position=Position.DEFENSEMAN) is now up for auction.
# SOLD: {'price': 4, 'winner': np.int64(3)}
# Player Athlete(mean=14.737809148691156, variance=11.640494225648599, position=Position.DEFENSEMAN) is now up for auction.
# SOLD: {'price': 4, 'winner': np.int64(3)}
# Player Athlete(mean=29.087086127376395, variance=25.727913251928424, position=Position.GOALIE) is now up for auction.
# SOLD: {'price': 5, 'winner': np.int64(1)}
# Player Athlete(mean=30.479199890146973, variance=4.957581646740579, position=Position.DEFENSEMAN) is now up for auction.
# SOLD: {'price': 5, 'winner': np.int64(2)}
# Player Athlete(mean=33.843899573265375, variance=39.90819554342989, position=Position.DEFENSEMAN) is now up for auction.
# SOLD: {'price': 9, 'winner': np.int64(0)}
# Player Athlete(mean=20.879575409418443, variance=8.224726631204899, position=Position.FORWARD) is now up for auction.
# SOLD: {'price': 3, 'winner': np.int64(0)}
# Player Athlete(mean=94.33377208917446, variance=141.96653671889322, position=Position.GOALIE) is now up for auction.
# SOLD: {'price': 5, 'winner': np.int64(2)}
# Player Athlete(mean=89.22644996105691, variance=10.213864398435403, position=Position.FORWARD) is now up for auction.
# SOLD: {'price': 18, 'winner': np.int64(0)}
# Player Athlete(mean=99.43981067511069, variance=78.90071194147082, position=Position.GOALIE) is now up for auction.
# SOLD: {'price': 4, 'winner': np.int64(2)}
# Player Athlete(mean=28.821799360389633, variance=8.714785591846837, position=Position.FORWARD) is now up for auction.
# SOLD: {'price': 4, 'winner': np.int64(3)}
# Player Athlete(mean=64.76988935240583, variance=7.119827812485319, position=Position.FORWARD) is now up for auction.
# SOLD: {'price': 7, 'winner': np.int64(3)}
# Player Athlete(mean=58.98039567649392, variance=6.25355178264325, position=Position.FORWARD) is now up for auction.
# SOLD: {'price': 5, 'winner': np.int64(5)}
# Player Athlete(mean=26.049475727368087, variance=3.4364410959132643, position=Position.FORWARD) is now up for auction.
# SOLD: {'price': 2, 'winner': np.int64(0)}
# Player Athlete(mean=28.98077985961011, variance=15.97646569193367, position=Position.GOALIE) is now up for auction.
# SOLD: {'price': 0, 'winner': np.int64(4)}
# Player Athlete(mean=26.53164875931629, variance=4.40574834528052, position=Position.DEFENSEMAN) is now up for auction.
# SOLD: {'price': 3, 'winner': np.int64(2)}
# Player Athlete(mean=37.985378754219695, variance=4.472856453207662, position=Position.DEFENSEMAN) is now up for auction.
# SOLD: {'price': 3, 'winner': np.int64(2)}
# Player Athlete(mean=40.17551004919885, variance=4.941576670384136, position=Position.FORWARD) is now up for auction.
# SOLD: {'price': 3, 'winner': np.int64(5)}
# Player Athlete(mean=14.454385301655652, variance=1.51945937955685, position=Position.DEFENSEMAN) is now up for auction.
# SOLD: {'price': 5, 'winner': np.int64(0)}
# Player Athlete(mean=128.477853679795, variance=31.06359668379405, position=Position.GOALIE) is now up for auction.
# SOLD: {'price': 0, 'winner': np.int64(1)}
# Player Athlete(mean=5.514691940006127, variance=9.968860474136841, position=Position.FORWARD) is now up for auction.
# SOLD: {'price': 1, 'winner': np.int64(1)}
# Player Athlete(mean=61.1269111053835, variance=7.400685514256459, position=Position.FORWARD) is now up for auction.
# SOLD: {'price': 4, 'winner': np.int64(5)}
# Player Athlete(mean=23.48637732914707, variance=6.231807865653389, position=Position.DEFENSEMAN) is now up for auction.
# SOLD: {'price': 2, 'winner': np.int64(2)}
# Player Athlete(mean=125.42009889299914, variance=16.976770550508608, position=Position.FORWARD) is now up for auction.
# SOLD: {'price': 9, 'winner': np.int64(5)}
# Player Athlete(mean=57.20711127811333, variance=8.88441685151178, position=Position.FORWARD) is now up for auction.
# SOLD: {'price': 5, 'winner': np.int64(5)}
# Player Athlete(mean=38.35212409024792, variance=6.599105574189995, position=Position.DEFENSEMAN) is now up for auction.
# SOLD: {'price': 1, 'winner': np.int64(5)}
# Player Athlete(mean=83.9970998616156, variance=8.4054921909825, position=Position.FORWARD) is now up for auction.
# SOLD: {'price': 7, 'winner': np.int64(5)}
# Player Athlete(mean=47.2727346254785, variance=5.790059469371176, position=Position.FORWARD) is now up for auction.
# SOLD: {'price': 5, 'winner': np.int64(5)}
# Player Athlete(mean=69.96581486189879, variance=11.33560368036962, position=Position.FORWARD) is now up for auction.
# SOLD: {'price': 7, 'winner': np.int64(5)}
# Player Athlete(mean=57.71741458709776, variance=6.476706179615746, position=Position.FORWARD) is now up for auction.
# SOLD: {'price': 4, 'winner': np.int64(2)}
# Player Athlete(mean=17.221122417360892, variance=2.236757818195948, position=Position.FORWARD) is now up for auction.
# SOLD: {'price': 2, 'winner': np.int64(1)}
# Player Athlete(mean=28.117240292584746, variance=4.188929550919588, position=Position.DEFENSEMAN) is now up for auction.
# SOLD: {'price': 1, 'winner': np.int64(5)}
# Player Athlete(mean=11.952287468119977, variance=4.064435852433551, position=Position.FORWARD) is now up for auction.
# SOLD: {'price': 1, 'winner': np.int64(2)}
# Player Athlete(mean=34.70590329447202, variance=79.40484086456061, position=Position.GOALIE) is now up for auction.
# SOLD: {'price': 0, 'winner': 0}
# Player Athlete(mean=12.490268847268919, variance=1.5993688010424354, position=Position.FORWARD) is now up for auction.
# SOLD: {'price': 1, 'winner': np.int64(2)}
# Player Athlete(mean=31.110219625472098, variance=10.530000761618878, position=Position.DEFENSEMAN) is now up for auction.
# SOLD: {'price': 1, 'winner': np.int64(5)}
# Player Athlete(mean=31.891159848377036, variance=4.370094082397324, position=Position.FORWARD) is now up for auction.
# SOLD: {'price': 2, 'winner': np.int64(2)}
# Player Athlete(mean=20.382314155799893, variance=5.66394814546318, position=Position.DEFENSEMAN) is now up for auction.
# SOLD: {'price': 2, 'winner': np.int64(1)}
# Player Athlete(mean=64.18133567895315, variance=12.721704958168258, position=Position.FORWARD) is now up for auction.
# SOLD: {'price': 4, 'winner': np.int64(2)}
# Player Athlete(mean=11.013236991102994, variance=16.957161775964675, position=Position.FORWARD) is now up for auction.
# SOLD: {'price': 1, 'winner': np.int64(2)}
# Player Athlete(mean=67.0969388981073, variance=6.883631113532101, position=Position.FORWARD) is now up for auction.
# SOLD: {'price': 1, 'winner': np.int64(2)}
# Player Athlete(mean=20.248830654750613, variance=2.0395565443787733, position=Position.FORWARD) is now up for auction.
# SOLD: {'price': 0, 'winner': np.int64(1)}
# Player Athlete(mean=4.256861374821428, variance=2.044852174851367, position=Position.DEFENSEMAN) is now up for auction.
# SOLD: {'price': 0, 'winner': np.int64(0)}
# Player Athlete(mean=27.211031584847834, variance=12.070443597430089, position=Position.DEFENSEMAN) is now up for auction.
# SOLD: {'price': 0, 'winner': np.int64(5)}
# Player Athlete(mean=36.91342855890723, variance=3.977487167512261, position=Position.FORWARD) is now up for auction.
# SOLD: {'price': 0, 'winner': np.int64(4)}
# Player Athlete(mean=25.540669690740945, variance=10.636287129694896, position=Position.FORWARD) is now up for auction.
# SOLD: {'price': 0, 'winner': np.int64(1)}
# Player Athlete(mean=83.04742366692363, variance=25.6040780843219, position=Position.FORWARD) is now up for auction.
# SOLD: {'price': 1, 'winner': np.int64(1)}
# Player Athlete(mean=51.0113707722143, variance=10.363612210769793, position=Position.FORWARD) is now up for auction.
# SOLD: {'price': 0, 'winner': np.int64(0)}
# Player Athlete(mean=48.98513319060327, variance=5.693584171440211, position=Position.FORWARD) is now up for auction.
# SOLD: {'price': 1, 'winner': np.int64(1)}
# Player Athlete(mean=34.70444947640257, variance=22.29104951317752, position=Position.DEFENSEMAN) is now up for auction.
# SOLD: {'price': 1, 'winner': np.int64(1)}
# Player Athlete(mean=9.22631703106378, variance=20.324159997974157, position=Position.DEFENSEMAN) is now up for auction.
# SOLD: {'price': 0, 'winner': np.int64(4)}
# Player Athlete(mean=10.796916551115704, variance=8.575135826123534, position=Position.FORWARD) is now up for auction.
# SOLD: {'price': 0, 'winner': np.int64(1)}
# Player Athlete(mean=55.43685086958216, variance=6.554442553135145, position=Position.FORWARD) is now up for auction.
# SOLD: {'price': 0, 'winner': np.int64(0)}
# Player Athlete(mean=24.285242477966662, variance=3.1627581075492257, position=Position.DEFENSEMAN) is now up for auction.
# SOLD: {'price': 0, 'winner': np.int64(1)}
# Player Athlete(mean=176.50825774259636, variance=19.214842386065058, position=Position.FORWARD) is now up for auction.
# SOLD: {'price': 1, 'winner': np.int64(1)}
# Player Athlete(mean=39.43481325612046, variance=9.793334209344422, position=Position.FORWARD) is now up for auction.
# SOLD: {'price': 0, 'winner': np.int64(0)}
# Player Athlete(mean=64.87307235851402, variance=159.87921498630317, position=Position.GOALIE) is now up for auction.
# SOLD: {'price': 0, 'winner': 0}
# Player Athlete(mean=85.41816322808153, variance=9.462088761568584, position=Position.FORWARD) is now up for auction.
# SOLD: {'price': 0, 'winner': 4}
# Player Athlete(mean=44.54442850405697, variance=5.050324712312614, position=Position.FORWARD) is now up for auction.
# SOLD: {'price': 0, 'winner': 4}
# Player Athlete(mean=10.64419031685548, variance=12.279614241676853, position=Position.DEFENSEMAN) is now up for auction.
# SOLD: {'price': 0, 'winner': np.int64(1)}
# Player Athlete(mean=8.721075759471146, variance=1.7543808022719807, position=Position.DEFENSEMAN) is now up for auction.
# SOLD: {'price': 0, 'winner': 0}
# Player Athlete(mean=12.418087729293442, variance=11.187077181442922, position=Position.FORWARD) is now up for auction.

# %%
specified = ['monte_carlo', 'flip', 'proportional', 'value_above_replacement', 'always_bid', 'proportional']
run_and_display_auction('../test_outputs/output1.txt', specified)

# %%
specified = ['monte_carlo']*6
run_and_display_auction('../test_outputs/output2.txt', specified)
# Out:
# Auctioning off:
# Position.FORWARD
# Athlete(mean=138.42691990786727, variance=22.276217522893074, position=Position.FORWARD), Rank: 1
# Athlete(mean=107.39081987073953, variance=17.29114594932529, position=Position.FORWARD), Rank: 2
# Athlete(mean=101.78494072491057, variance=18.879135996061223, position=Position.FORWARD), Rank: 3
# Athlete(mean=92.21439527766944, variance=10.149922459350167, position=Position.FORWARD), Rank: 4
# Athlete(mean=87.82717640195764, variance=14.524769507140391, position=Position.FORWARD), Rank: 5
# Athlete(mean=81.6274332767526, variance=10.442815377295755, position=Position.FORWARD), Rank: 6
# Athlete(mean=81.50951269492096, variance=15.759851161531072, position=Position.FORWARD), Rank: 7
# Athlete(mean=81.16794114861025, variance=14.168903050153073, position=Position.FORWARD), Rank: 8
# Athlete(mean=74.65378581753842, variance=7.793754815032662, position=Position.FORWARD), Rank: 9
# Athlete(mean=72.78605195062005, variance=8.159192470995547, position=Position.FORWARD), Rank: 10
# Athlete(mean=69.12293845310164, variance=7.2372360120492125, position=Position.FORWARD), Rank: 11
# Athlete(mean=64.69719881337005, variance=8.1034167187333, position=Position.FORWARD), Rank: 12
# Athlete(mean=63.5922248206461, variance=9.233911214155116, position=Position.FORWARD), Rank: 13
# Athlete(mean=62.54751329018365, variance=7.4161467523441935, position=Position.FORWARD), Rank: 14
# Athlete(mean=59.697382718783764, variance=7.379596736868071, position=Position.FORWARD), Rank: 15
# Athlete(mean=58.35602204196745, variance=6.502927102853016, position=Position.FORWARD), Rank: 16
# Athlete(mean=53.95828370724779, variance=5.835068463202047, position=Position.FORWARD), Rank: 17
# Athlete(mean=53.90951296599451, variance=9.120406479300732, position=Position.FORWARD), Rank: 18
# Athlete(mean=53.36412750854122, variance=6.9322815282045305, position=Position.FORWARD), Rank: 19
# Athlete(mean=52.908855193774286, variance=5.362561555597276, position=Position.FORWARD), Rank: 20
# Athlete(mean=52.37490895476878, variance=5.50898400245649, position=Position.FORWARD), Rank: 21
# Athlete(mean=52.0918468439757, variance=7.301035639063116, position=Position.FORWARD), Rank: 22
# Athlete(mean=49.36926505600776, variance=13.680332529731947, position=Position.FORWARD), Rank: 23
# Athlete(mean=48.20342734129767, variance=6.428081462854813, position=Position.FORWARD), Rank: 24
# Athlete(mean=48.05570867151475, variance=12.623406091094092, position=Position.FORWARD), Rank: 25
# Athlete(mean=46.43703506380671, variance=9.568130931648074, position=Position.FORWARD), Rank: 26
# Athlete(mean=45.94157283049765, variance=10.249847361176949, position=Position.FORWARD), Rank: 27
# Athlete(mean=43.81097830308383, variance=6.723559537804459, position=Position.FORWARD), Rank: 28
# Athlete(mean=43.666594876088624, variance=4.600057189551274, position=Position.FORWARD), Rank: 29
# Athlete(mean=41.03071038616378, variance=6.804485663180045, position=Position.FORWARD), Rank: 30
# Athlete(mean=39.02847362962115, variance=5.180041299607994, position=Position.FORWARD), Rank: 31
# Athlete(mean=38.86369238900642, variance=7.5238823426915875, position=Position.FORWARD), Rank: 32
# Athlete(mean=37.43098560388207, variance=7.951094496909002, position=Position.FORWARD), Rank: 33
# Athlete(mean=36.72530278688425, variance=5.159617385941159, position=Position.FORWARD), Rank: 34
# Athlete(mean=36.43043340824859, variance=5.975688551764655, position=Position.FORWARD), Rank: 35
# Athlete(mean=35.40258699793927, variance=10.873811933811576, position=Position.FORWARD), Rank: 36
# Athlete(mean=35.16769377168872, variance=3.670638721448504, position=Position.FORWARD), Rank: 37
# Athlete(mean=30.32723994608113, variance=5.565980426163783, position=Position.FORWARD), Rank: 38
# Athlete(mean=30.1976728825254, variance=17.460454543421378, position=Position.FORWARD), Rank: 39
# Athlete(mean=23.702535146436723, variance=6.31965293082272, position=Position.FORWARD), Rank: 40
# Athlete(mean=23.323666972908597, variance=2.417915992259162, position=Position.FORWARD), Rank: 41
# Athlete(mean=22.919724229250118, variance=2.30151196066495, position=Position.FORWARD), Rank: 42
# Athlete(mean=22.811288426360697, variance=3.866775000622983, position=Position.FORWARD), Rank: 43
# Athlete(mean=19.78429104962605, variance=5.348518495412273, position=Position.FORWARD), Rank: 44
# Athlete(mean=19.356969237031283, variance=4.262599425654553, position=Position.FORWARD), Rank: 45
# Athlete(mean=13.927329358046043, variance=1.395286258358819, position=Position.FORWARD), Rank: 46
# Athlete(mean=12.789781281273651, variance=2.0114658093745756, position=Position.FORWARD), Rank: 47
# Athlete(mean=11.224459298057123, variance=7.788610662615325, position=Position.FORWARD), Rank: 48
# Position.DEFENSEMAN
# Athlete(mean=75.64263571138864, variance=22.036054551076457, position=Position.DEFENSEMAN), Rank: 1
# Athlete(mean=56.97567857635163, variance=5.838486300425748, position=Position.DEFENSEMAN), Rank: 2
# Athlete(mean=50.3090538693306, variance=7.206057199904194, position=Position.DEFENSEMAN), Rank: 3
# Athlete(mean=49.79303488422964, variance=12.267379195606704, position=Position.DEFENSEMAN), Rank: 4
# Athlete(mean=45.0318343446997, variance=6.822484194676083, position=Position.DEFENSEMAN), Rank: 5
# Athlete(mean=43.971334823055706, variance=18.09340700328929, position=Position.DEFENSEMAN), Rank: 6
# Athlete(mean=42.24429761915201, variance=9.217825227707324, position=Position.DEFENSEMAN), Rank: 7
# Athlete(mean=40.31093112144255, variance=18.3334002440246, position=Position.DEFENSEMAN), Rank: 8
# Athlete(mean=40.17849935230843, variance=9.399494593104567, position=Position.DEFENSEMAN), Rank: 9
# Athlete(mean=33.881009795611384, variance=12.350312542516328, position=Position.DEFENSEMAN), Rank: 10
# Athlete(mean=33.86712711054165, variance=4.562873378575579, position=Position.DEFENSEMAN), Rank: 11
# Athlete(mean=31.376490790688905, variance=3.7210082091683936, position=Position.DEFENSEMAN), Rank: 12
# Athlete(mean=30.394929430499154, variance=3.4603583255408723, position=Position.DEFENSEMAN), Rank: 13
# Athlete(mean=29.19787160343182, variance=2.9867034147799036, position=Position.DEFENSEMAN), Rank: 14
# Athlete(mean=28.901236271032523, variance=38.127743527569066, position=Position.DEFENSEMAN), Rank: 15
# Athlete(mean=27.046125171133262, variance=5.248965318848672, position=Position.DEFENSEMAN), Rank: 16
# Athlete(mean=24.053130983785955, variance=3.3065136904516446, position=Position.DEFENSEMAN), Rank: 17
# Athlete(mean=22.839290194374545, variance=7.4354928366175255, position=Position.DEFENSEMAN), Rank: 18
# Athlete(mean=17.684352456728572, variance=2.217770179360362, position=Position.DEFENSEMAN), Rank: 19
# Athlete(mean=13.556115483461415, variance=8.84205858675735, position=Position.DEFENSEMAN), Rank: 20
# Athlete(mean=12.224676389358445, variance=1.622005588724726, position=Position.DEFENSEMAN), Rank: 21
# Athlete(mean=11.970683366219394, variance=1.5623550574037843, position=Position.DEFENSEMAN), Rank: 22
# Athlete(mean=7.9388295272919995, variance=0.8821398129185173, position=Position.DEFENSEMAN), Rank: 23
# Athlete(mean=4.616787506719944, variance=2.4855981852558773, position=Position.DEFENSEMAN), Rank: 24
# Position.GOALIE
# Athlete(mean=177.47478588681196, variance=33.01787349890356, position=Position.GOALIE), Rank: 1
# Athlete(mean=105.02255703952912, variance=47.78154489573347, position=Position.GOALIE), Rank: 2
# Athlete(mean=73.80418749166822, variance=47.54263511488457, position=Position.GOALIE), Rank: 3
# Athlete(mean=55.57108121361509, variance=45.821863656327714, position=Position.GOALIE), Rank: 4
# Athlete(mean=47.03850568993366, variance=42.834324920753026, position=Position.GOALIE), Rank: 5
# Athlete(mean=44.06707806833652, variance=57.07595008750384, position=Position.GOALIE), Rank: 6
# Athlete(mean=42.07219782591996, variance=105.604014825608, position=Position.GOALIE), Rank: 7
# Athlete(mean=37.965443060612685, variance=71.44040161145978, position=Position.GOALIE), Rank: 8
# Athlete(mean=34.40081557639389, variance=28.446232486624716, position=Position.GOALIE), Rank: 9
# Athlete(mean=20.448954765688924, variance=32.24812307719002, position=Position.GOALIE), Rank: 10
# Athlete(mean=13.404061301884242, variance=104.16321674845982, position=Position.GOALIE), Rank: 11
# Athlete(mean=11.957619111514525, variance=10.208420915493592, position=Position.GOALIE), Rank: 12
# {0: {'type': 'monte_carlo', 'num_simulations': 81}, 1: {'type': 'flip', 'p': 0.7311828136457603}, 2: {'type': 'proportional', 'weight_vector': [0.4968437952291435, 0.4336350013155689, 0.06952120345528755]}, 3: {'type': 'value_above_replacement'}, 4: {'type': 'monte_carlo', 'num_simulations': 109}, 5: {'type': 'monte_carlo', 'num_simulations': 108}}
# {0: {'type': 'monte_carlo', 'num_simulations': 81}, 1: {'type': 'flip', 'p': 0.7311828136457603}, 2: {'type': 'proportional', 'weight_vector': [0.4968437952291435, 0.4336350013155689, 0.06952120345528755]}, 3: {'type': 'value_above_replacement'}, 4: {'type': 'monte_carlo', 'num_simulations': 109}, 5: {'type': 'monte_carlo', 'num_simulations': 108}}
# {0: {'type': 'monte_carlo', 'num_simulations': 81}, 1: {'type': 'flip', 'p': 0.7311828136457603}, 2: {'type': 'proportional', 'weight_vector': [0.4968437952291435, 0.4336350013155689, 0.06952120345528755]}, 3: {'type': 'value_above_replacement'}, 4: {'type': 'monte_carlo', 'num_simulations': 109}, 5: {'type': 'monte_carlo', 'num_simulations': 108}}
# {0: {'type': 'monte_carlo', 'num_simulations': 81}, 1: {'type': 'flip', 'p': 0.7311828136457603}, 2: {'type': 'proportional', 'weight_vector': [0.4968437952291435, 0.4336350013155689, 0.06952120345528755]}, 3: {'type': 'value_above_replacement'}, 4: {'type': 'monte_carlo', 'num_simulations': 109}, 5: {'type': 'monte_carlo', 'num_simulations': 108}}
# {0: {'type': 'monte_carlo', 'num_simulations': 81}, 1: {'type': 'flip', 'p': 0.7311828136457603}, 2: {'type': 'proportional', 'weight_vector': [0.4968437952291435, 0.4336350013155689, 0.06952120345528755]}, 3: {'type': 'value_above_replacement'}, 4: {'type': 'monte_carlo', 'num_simulations': 109}, 5: {'type': 'monte_carlo', 'num_simulations': 108}}
# {0: {'type': 'monte_carlo', 'num_simulations': 81}, 1: {'type': 'flip', 'p': 0.7311828136457603}, 2: {'type': 'proportional', 'weight_vector': [0.4968437952291435, 0.4336350013155689, 0.06952120345528755]}, 3: {'type': 'value_above_replacement'}, 4: {'type': 'monte_carlo', 'num_simulations': 109}, 5: {'type': 'monte_carlo', 'num_simulations': 108}}
#
#
#
#
#
#
#
#
#
#
# Player Athlete(mean=45.94157283049765, variance=10.249847361176949, position=Position.FORWARD) is now up for auction.
# SOLD: {'price': 10, 'winner': np.int64(3)}
# Player Athlete(mean=22.839290194374545, variance=7.4354928366175255, position=Position.DEFENSEMAN) is now up for auction.
# SOLD: {'price': 10, 'winner': np.int64(3)}
# Player Athlete(mean=17.684352456728572, variance=2.217770179360362, position=Position.DEFENSEMAN) is now up for auction.
# SOLD: {'price': 6, 'winner': np.int64(3)}
# Player Athlete(mean=40.17849935230843, variance=9.399494593104567, position=Position.DEFENSEMAN) is now up for auction.
# SOLD: {'price': 13, 'winner': np.int64(3)}
# Player Athlete(mean=34.40081557639389, variance=28.446232486624716, position=Position.GOALIE) is now up for auction.
# SOLD: {'price': 14, 'winner': np.int64(3)}
# Player Athlete(mean=43.81097830308383, variance=6.723559537804459, position=Position.FORWARD) is now up for auction.
# SOLD: {'price': 9, 'winner': np.int64(1)}
# Player Athlete(mean=42.24429761915201, variance=9.217825227707324, position=Position.DEFENSEMAN) is now up for auction.
# SOLD: {'price': 15, 'winner': np.int64(3)}
# Player Athlete(mean=31.376490790688905, variance=3.7210082091683936, position=Position.DEFENSEMAN) is now up for auction.
# SOLD: {'price': 12, 'winner': np.int64(5)}
# Player Athlete(mean=75.64263571138864, variance=22.036054551076457, position=Position.DEFENSEMAN) is now up for auction.
# SOLD: {'price': 27, 'winner': np.int64(5)}
# Player Athlete(mean=13.556115483461415, variance=8.84205858675735, position=Position.DEFENSEMAN) is now up for auction.
# SOLD: {'price': 2, 'winner': np.int64(2)}
# Player Athlete(mean=23.702535146436723, variance=6.31965293082272, position=Position.FORWARD) is now up for auction.
# SOLD: {'price': 3, 'winner': np.int64(3)}
# Player Athlete(mean=27.046125171133262, variance=5.248965318848672, position=Position.DEFENSEMAN) is now up for auction.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 specified = ['monte_carlo', 'flip', 'proportional', 'value_above_replacement', 'monte_carlo', 'monte_carlo']
# ----> 2 run_and_display_auction('../test_outputs/output2.txt', specified)
#
# Cell In[2], line 41, in run_and_display_auction(output_file_path, specified)
#      39 strategies = generate_random_strategies(specified)
#      40 export_file = 'auction_results.txt'
# ---> 41 run_auction(export_file, strategies)
#      43 with open(export_file, 'r') as file:
#      44     lines = file.readlines()
#
# File ~/Documents/School/2024-2025/STAT4830/STAT-4830-sparsh-project/src/benchmark_auctions.py:267, in run_auction(export_file, strategies_dict)
#     264 strategy = player_strategies[current_bidder]
#     265 if isinstance(strategy, MONTE_CARLO_STRATEGY):
#     266     #print("MONTE CARLO STRAT")
# --> 267     action = strategy.monte_carlo_strategy()
#     268 elif isinstance(strategy, FLIP):
#     269     #print("FLIP STRAT")
#     270     action = strategy.flip_strategy()
#
# File ~/Documents/School/2024-2025/STAT4830/STAT-4830-sparsh-project/src/benchmark_auctions.py:38, in MONTE_CARLO_STRATEGY.monte_carlo_strategy(self)
#      35 num_processes = 4
#      36 simulations_per_process = self.num_simulations // num_processes
# ---> 38 scores = run_multiprocessing(self.env, num_processes, simulations_per_process) #run_single_core(self.env, num_processes, simulations_per_process)
#      39 for action, score in scores.items():
#      40     action_text = "pass" if action == 0 else "bid"
#
# File ~/Documents/School/2024-2025/STAT4830/STAT-4830-sparsh-project/src/benchmark_auctions.py:58, in run_multiprocessing(env, num_processes, simulations_per_process)
#      56 with Pool(num_processes) as pool:
#      57     for action in range(env.action_space.n):
# ---> 58         action_scores = pool.map(MONTE_CARLO_STRATEGY.monte_carlo_worker, [(env, action, simulations_per_process) for _ in range(num_processes)])
#      59         scores[action] = np.mean(action_scores)
#      60 return scores
#
# File ~/anaconda3/envs/stat4830/lib/python3.9/multiprocessing/pool.py:364, in Pool.map(self, func, iterable, chunksize)
#     359 def map(self, func, iterable, chunksize=None):
#     360     '''
#     361     Apply `func` to each element in `iterable`, collecting the results
#     362     in a list that is returned.
#     363     '''
# --> 364     return self._map_async(func, iterable, mapstar, chunksize).get()
#
# File ~/anaconda3/envs/stat4830/lib/python3.9/multiprocessing/pool.py:765, in ApplyResult.get(self, timeout)
#     764 def get(self, timeout=None):
# --> 765     self.wait(timeout)
#     766     if not self.ready():
#     767         raise TimeoutError
#
# File ~/anaconda3/envs/stat4830/lib/python3.9/multiprocessing/pool.py:762, in ApplyResult.wait(self, timeout)
#     761 def wait(self, timeout=None):
# --> 762     self._event.wait(timeout)
#
# File ~/anaconda3/envs/stat4830/lib/python3.9/threading.py:581, in Event.wait(self, timeout)
#     579 signaled = self._flag
#     580 if not signaled:
# --> 581     signaled = self._cond.wait(timeout)
#     582 return signaled
#
# File ~/anaconda3/envs/stat4830/lib/python3.9/threading.py:312, in Condition.wait(self, timeout)
#     310 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     311     if timeout is None:
# --> 312         waiter.acquire()
#     313         gotit = True
#     314     else:
#
# KeyboardInterrupt:

# %%
for i in range(20):
    print(i+3)
    run_and_display_auction(f'../test_outputs/output{i+3}.txt')
# Out:
# Auctioning off:
# Player Athlete(mean=52.723285615159874, variance=5.380844905796894, position=Position.DEFENSEMAN), Rank: 1)
# Player Athlete(mean=94.91947494334099, variance=100.70244830259139, position=Position.GOALIE), Rank: 1)
# Player Athlete(mean=152.6466695394919, variance=15.98366781445402, position=Position.FORWARD), Rank: 1)
# Player Athlete(mean=130.72417911172727, variance=15.70424896694717, position=Position.FORWARD), Rank: 2)
# Player Athlete(mean=92.83914488425928, variance=57.011942377802576, position=Position.GOALIE), Rank: 2)
# Player Athlete(mean=47.37087121488046, variance=4.919599838168949, position=Position.DEFENSEMAN), Rank: 2)
# Player Athlete(mean=122.54956204063936, variance=12.659329151353962, position=Position.FORWARD), Rank: 3)
# Player Athlete(mean=44.81871874013402, variance=7.995330465982706, position=Position.DEFENSEMAN), Rank: 3)
# Player Athlete(mean=79.35453275087191, variance=18.26445446040696, position=Position.GOALIE), Rank: 3)
# Player Athlete(mean=99.90106819942855, variance=11.847788783947664, position=Position.FORWARD), Rank: 4)
# Player Athlete(mean=66.28439959921594, variance=62.584267575182515, position=Position.GOALIE), Rank: 4)
# Player Athlete(mean=40.90409005673647, variance=4.328735579904755, position=Position.DEFENSEMAN), Rank: 4)
# Player Athlete(mean=61.21794811582355, variance=65.42595966439659, position=Position.GOALIE), Rank: 5)
# Player Athlete(mean=32.12262514520537, variance=7.534246648851526, position=Position.DEFENSEMAN), Rank: 5)
# Player Athlete(mean=92.15701069339684, variance=9.455290838437941, position=Position.FORWARD), Rank: 5)
# Player Athlete(mean=30.716143846978966, variance=5.532889972340123, position=Position.DEFENSEMAN), Rank: 6)
# Player Athlete(mean=43.99721212141294, variance=37.22330373254823, position=Position.GOALIE), Rank: 6)
# Player Athlete(mean=90.14193813392342, variance=12.178612873528342, position=Position.FORWARD), Rank: 6)
# Player Athlete(mean=36.454625285777695, variance=75.92472553870462, position=Position.GOALIE), Rank: 7)
# Player Athlete(mean=24.50216095784174, variance=2.451461572496454, position=Position.DEFENSEMAN), Rank: 7)
# Player Athlete(mean=88.86900365282449, variance=11.431859279645975, position=Position.FORWARD), Rank: 7)
# Player Athlete(mean=24.42836226981952, variance=3.5228169279528485, position=Position.DEFENSEMAN), Rank: 8)
# Player Athlete(mean=82.25613129949048, variance=16.300489699568175, position=Position.FORWARD), Rank: 8)
# Player Athlete(mean=30.979622606002216, variance=37.858149254617125, position=Position.GOALIE), Rank: 8)
# Player Athlete(mean=77.4164349005584, variance=12.628816000110904, position=Position.FORWARD), Rank: 9)
# Player Athlete(mean=23.98750422179645, variance=2.9299939818175194, position=Position.DEFENSEMAN), Rank: 9)
# Player Athlete(mean=30.359820941143735, variance=36.84670421673476, position=Position.GOALIE), Rank: 9)
# Player Athlete(mean=21.07079983295048, variance=76.21383228101162, position=Position.GOALIE), Rank: 10)
# Player Athlete(mean=74.76017623060373, variance=19.607628336252304, position=Position.FORWARD), Rank: 10)
# Player Athlete(mean=23.760040851998838, variance=2.527869205937997, position=Position.DEFENSEMAN), Rank: 10)
# Player Athlete(mean=21.427977136476247, variance=22.330194780065987, position=Position.DEFENSEMAN), Rank: 11)
# Player Athlete(mean=71.38109120065104, variance=8.248620163943265, position=Position.FORWARD), Rank: 11)
# Player Athlete(mean=18.717176333095477, variance=35.77914625409218, position=Position.GOALIE), Rank: 11)
# Player Athlete(mean=17.169119424852717, variance=4.914028118232739, position=Position.DEFENSEMAN), Rank: 12)
# Player Athlete(mean=14.044543365142708, variance=131.15861245940488, position=Position.GOALIE), Rank: 12)
# Player Athlete(mean=67.90046320784862, variance=16.73165495719268, position=Position.FORWARD), Rank: 12)
# Player Athlete(mean=13.430148312283169, variance=4.046898639932882, position=Position.DEFENSEMAN), Rank: 13)
# Player Athlete(mean=66.66609488620958, variance=7.682147831023374, position=Position.FORWARD), Rank: 13)
# Player Athlete(mean=12.984832087053864, variance=2.34064599952963, position=Position.DEFENSEMAN), Rank: 14)
# Player Athlete(mean=66.2325071183153, variance=6.625996831382306, position=Position.FORWARD), Rank: 14)
# Player Athlete(mean=12.766334675736392, variance=1.2831771161758434, position=Position.DEFENSEMAN), Rank: 15)
# Player Athlete(mean=60.07578656092308, variance=9.023381940643496, position=Position.FORWARD), Rank: 15)
# Player Athlete(mean=57.11457153162155, variance=8.680937333655988, position=Position.FORWARD), Rank: 16)
# Player Athlete(mean=56.64713717631977, variance=6.487553582506228, position=Position.FORWARD), Rank: 17)
# Player Athlete(mean=10.660399797888392, variance=2.3434680661048164, position=Position.DEFENSEMAN), Rank: 17)
# Player Athlete(mean=9.671322336434027, variance=2.242291650798638, position=Position.DEFENSEMAN), Rank: 18)
# Player Athlete(mean=53.70231585903778, variance=25.089783324617404, position=Position.FORWARD), Rank: 18)
# Player Athlete(mean=7.268503816423875, variance=0.8804746659707382, position=Position.DEFENSEMAN), Rank: 19)
# Player Athlete(mean=48.97231744625259, variance=7.394994174140038, position=Position.FORWARD), Rank: 19)
# Player Athlete(mean=6.497305449893519, variance=2.4098543480179013, position=Position.DEFENSEMAN), Rank: 20)
# Player Athlete(mean=47.32944706725838, variance=4.751790363451515, position=Position.FORWARD), Rank: 20)
# Player Athlete(mean=5.871575596093836, variance=1.2659315372071305, position=Position.DEFENSEMAN), Rank: 21)
# Player Athlete(mean=47.04447438471738, variance=8.350797652323836, position=Position.FORWARD), Rank: 21)
# Player Athlete(mean=4.957709514426482, variance=0.621899497660508, position=Position.DEFENSEMAN), Rank: 22)
# Player Athlete(mean=45.887211689612386, variance=5.040117161650911, position=Position.FORWARD), Rank: 22)
# Player Athlete(mean=44.9731978855373, variance=4.554879439267699, position=Position.FORWARD), Rank: 23)
# Player Athlete(mean=3.7917214918567894, variance=0.6156715894225022, position=Position.DEFENSEMAN), Rank: 23)
# Player Athlete(mean=44.29410745938601, variance=4.471785691311063, position=Position.FORWARD), Rank: 24)
# Player Athlete(mean=3.0053968456564015, variance=2.2865556882197975, position=Position.DEFENSEMAN), Rank: 24)
# Player Athlete(mean=42.34960455420858, variance=4.256219292476654, position=Position.FORWARD), Rank: 25)
# Player Athlete(mean=41.78871255640894, variance=4.413157951111728, position=Position.FORWARD), Rank: 26)
# Player Athlete(mean=39.972059623798856, variance=4.0525884745033585, position=Position.FORWARD), Rank: 27)
# Player Athlete(mean=39.16139305730317, variance=4.3042927158507585, position=Position.FORWARD), Rank: 28)
# Player Athlete(mean=38.54348255787944, variance=4.510268492283823, position=Position.FORWARD), Rank: 29)
# Player Athlete(mean=38.34789302510171, variance=4.0445231572586025, position=Position.FORWARD), Rank: 30)
# Player Athlete(mean=37.84481583027739, variance=8.148587288238605, position=Position.FORWARD), Rank: 31)
# Player Athlete(mean=37.00041836231214, variance=6.718014835844153, position=Position.FORWARD), Rank: 32)
# Player Athlete(mean=36.30221280377201, variance=4.424876786361238, position=Position.FORWARD), Rank: 33)
# Player Athlete(mean=36.27762895813529, variance=6.7073649224857315, position=Position.FORWARD), Rank: 34)
# Player Athlete(mean=35.81297798021199, variance=9.79352180121471, position=Position.FORWARD), Rank: 35)
# Player Athlete(mean=35.438269582090584, variance=5.312742807352036, position=Position.FORWARD), Rank: 36)
# Player Athlete(mean=33.740794530165545, variance=7.654178945760929, position=Position.FORWARD), Rank: 37)
# Player Athlete(mean=32.50121930303066, variance=5.534941822350225, position=Position.FORWARD), Rank: 38)
# Player Athlete(mean=29.25959143580199, variance=3.2999237735966993, position=Position.FORWARD), Rank: 39)
# Player Athlete(mean=28.75032927887775, variance=4.082934457486641, position=Position.FORWARD), Rank: 40)
# Player Athlete(mean=28.601163515754124, variance=3.6866440259777247, position=Position.FORWARD), Rank: 41)
# Player Athlete(mean=21.743018686235665, variance=3.1128058354027663, position=Position.FORWARD), Rank: 42)
# Player Athlete(mean=19.80260183925549, variance=2.9038884763471184, position=Position.FORWARD), Rank: 43)
# Player Athlete(mean=18.03359517172067, variance=2.7575564794056104, position=Position.FORWARD), Rank: 44)
# Player Athlete(mean=17.920148515334507, variance=1.8869095987990139, position=Position.FORWARD), Rank: 45)
# Player Athlete(mean=17.750967517612484, variance=11.232887557992749, position=Position.FORWARD), Rank: 46)
# Player Athlete(mean=11.967194375443045, variance=2.0845372904797097, position=Position.FORWARD), Rank: 47)
# Player Athlete(mean=5.735199005769594, variance=0.612157097886666, position=Position.FORWARD), Rank: 48)
# 3 is deciding whether to pass or bid. Current bid is 0 for Athlete(mean=11.238766004942951, variance=1.21966024387643, position=Position.DEFENSEMAN)
# This player is ranked 16
# PROPORTIONAL STRAT
# Decision: bid
# 4 is deciding whether to pass or bid. Current bid is 1 for Athlete(mean=11.238766004942951, variance=1.21966024387643, position=Position.DEFENSEMAN)
# This player is ranked 16
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 5 is deciding whether to pass or bid. Current bid is 2 for Athlete(mean=11.238766004942951, variance=1.21966024387643, position=Position.DEFENSEMAN)
# This player is ranked 16
# PROPORTIONAL STRAT
# Decision: pass
# 0 is deciding whether to pass or bid. Current bid is 2 for Athlete(mean=11.238766004942951, variance=1.21966024387643, position=Position.DEFENSEMAN)
# This player is ranked 16
# MONTE CARLO STRAT
# Action: pass, Score: 3.587766901408451
# Action: bid, Score: 3.508482394366197
# Decision: pass
# 1 is deciding whether to pass or bid. Current bid is 2 for Athlete(mean=11.238766004942951, variance=1.21966024387643, position=Position.DEFENSEMAN)
# This player is ranked 16
# MONTE CARLO STRAT
# Action: pass, Score: 3.445295054945056
# Action: bid, Score: 3.451141758241759
# Decision: bid
# 2 is deciding whether to pass or bid. Current bid is 3 for Athlete(mean=11.238766004942951, variance=1.21966024387643, position=Position.DEFENSEMAN)
# This player is ranked 16
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 3 is deciding whether to pass or bid. Current bid is 4 for Athlete(mean=11.238766004942951, variance=1.21966024387643, position=Position.DEFENSEMAN)
# This player is ranked 16
# PROPORTIONAL STRAT
# Decision: bid
# 4 is deciding whether to pass or bid. Current bid is 5 for Athlete(mean=11.238766004942951, variance=1.21966024387643, position=Position.DEFENSEMAN)
# This player is ranked 16
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 1 is deciding whether to pass or bid. Current bid is 6 for Athlete(mean=11.238766004942951, variance=1.21966024387643, position=Position.DEFENSEMAN)
# This player is ranked 16
# MONTE CARLO STRAT
# Action: pass, Score: 3.5966898351648346
# Action: bid, Score: 3.4986104395604403
# Decision: pass
# 2 is deciding whether to pass or bid. Current bid is 6 for Athlete(mean=11.238766004942951, variance=1.21966024387643, position=Position.DEFENSEMAN)
# This player is ranked 16
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 3 is deciding whether to pass or bid. Current bid is 7 for Athlete(mean=11.238766004942951, variance=1.21966024387643, position=Position.DEFENSEMAN)
# This player is ranked 16
# PROPORTIONAL STRAT
# Decision: bid
# 4 is deciding whether to pass or bid. Current bid is 8 for Athlete(mean=11.238766004942951, variance=1.21966024387643, position=Position.DEFENSEMAN)
# This player is ranked 16
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 2 is deciding whether to pass or bid. Current bid is 9 for Athlete(mean=11.238766004942951, variance=1.21966024387643, position=Position.DEFENSEMAN)
# This player is ranked 16
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 3 is deciding whether to pass or bid. Current bid is 10 for Athlete(mean=11.238766004942951, variance=1.21966024387643, position=Position.DEFENSEMAN)
# This player is ranked 16
# PROPORTIONAL STRAT
# Decision: pass
# 4 is deciding whether to pass or bid. Current bid is 10 for Athlete(mean=11.238766004942951, variance=1.21966024387643, position=Position.DEFENSEMAN)
# This player is ranked 16
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 2 is deciding whether to pass or bid. Current bid is 11 for Athlete(mean=11.238766004942951, variance=1.21966024387643, position=Position.DEFENSEMAN)
# This player is ranked 16
# VALUE ABOVE REPLACEMENT STRAT
# Decision: pass
# 3 is deciding whether to pass or bid. Current bid is 0 for Athlete(mean=3.0053968456564015, variance=2.2865556882197975, position=Position.DEFENSEMAN)
# This player is ranked 24
# PROPORTIONAL STRAT
# Decision: bid
# 4 is deciding whether to pass or bid. Current bid is 1 for Athlete(mean=3.0053968456564015, variance=2.2865556882197975, position=Position.DEFENSEMAN)
# This player is ranked 24
# VALUE ABOVE REPLACEMENT STRAT
# Decision: pass
# 5 is deciding whether to pass or bid. Current bid is 1 for Athlete(mean=3.0053968456564015, variance=2.2865556882197975, position=Position.DEFENSEMAN)
# This player is ranked 24
# PROPORTIONAL STRAT
# Decision: pass
# 0 is deciding whether to pass or bid. Current bid is 1 for Athlete(mean=3.0053968456564015, variance=2.2865556882197975, position=Position.DEFENSEMAN)
# This player is ranked 24
# MONTE CARLO STRAT
# Action: pass, Score: 3.7270521126760565
# Action: bid, Score: 3.435606338028169
# Decision: pass
# 1 is deciding whether to pass or bid. Current bid is 1 for Athlete(mean=3.0053968456564015, variance=2.2865556882197975, position=Position.DEFENSEMAN)
# This player is ranked 24
# MONTE CARLO STRAT
# Action: pass, Score: 3.391683516483517
# Action: bid, Score: 3.6731219780219777
# Decision: bid
# 2 is deciding whether to pass or bid. Current bid is 2 for Athlete(mean=3.0053968456564015, variance=2.2865556882197975, position=Position.DEFENSEMAN)
# This player is ranked 24
# VALUE ABOVE REPLACEMENT STRAT
# Decision: pass
# 3 is deciding whether to pass or bid. Current bid is 2 for Athlete(mean=3.0053968456564015, variance=2.2865556882197975, position=Position.DEFENSEMAN)
# This player is ranked 24
# PROPORTIONAL STRAT
# Decision: pass
# 4 is deciding whether to pass or bid. Current bid is 0 for Athlete(mean=23.760040851998838, variance=2.527869205937997, position=Position.DEFENSEMAN)
# This player is ranked 10
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 5 is deciding whether to pass or bid. Current bid is 1 for Athlete(mean=23.760040851998838, variance=2.527869205937997, position=Position.DEFENSEMAN)
# This player is ranked 10
# PROPORTIONAL STRAT
# Decision: bid
# 0 is deciding whether to pass or bid. Current bid is 2 for Athlete(mean=23.760040851998838, variance=2.527869205937997, position=Position.DEFENSEMAN)
# This player is ranked 10
# MONTE CARLO STRAT
# Action: pass, Score: 3.4141457746478876
# Action: bid, Score: 3.4038612676056332
# Decision: pass
# 1 is deciding whether to pass or bid. Current bid is 2 for Athlete(mean=23.760040851998838, variance=2.527869205937997, position=Position.DEFENSEMAN)
# This player is ranked 10
# MONTE CARLO STRAT
# Action: pass, Score: 3.4167543956043955
# Action: bid, Score: 3.2029840659340656
# Decision: pass
# 2 is deciding whether to pass or bid. Current bid is 2 for Athlete(mean=23.760040851998838, variance=2.527869205937997, position=Position.DEFENSEMAN)
# This player is ranked 10
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 3 is deciding whether to pass or bid. Current bid is 3 for Athlete(mean=23.760040851998838, variance=2.527869205937997, position=Position.DEFENSEMAN)
# This player is ranked 10
# PROPORTIONAL STRAT
# Decision: bid
# 4 is deciding whether to pass or bid. Current bid is 4 for Athlete(mean=23.760040851998838, variance=2.527869205937997, position=Position.DEFENSEMAN)
# This player is ranked 10
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 5 is deciding whether to pass or bid. Current bid is 5 for Athlete(mean=23.760040851998838, variance=2.527869205937997, position=Position.DEFENSEMAN)
# This player is ranked 10
# PROPORTIONAL STRAT
# Decision: pass
# 2 is deciding whether to pass or bid. Current bid is 5 for Athlete(mean=23.760040851998838, variance=2.527869205937997, position=Position.DEFENSEMAN)
# This player is ranked 10
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 3 is deciding whether to pass or bid. Current bid is 6 for Athlete(mean=23.760040851998838, variance=2.527869205937997, position=Position.DEFENSEMAN)
# This player is ranked 10
# PROPORTIONAL STRAT
# Decision: bid
# 4 is deciding whether to pass or bid. Current bid is 7 for Athlete(mean=23.760040851998838, variance=2.527869205937997, position=Position.DEFENSEMAN)
# This player is ranked 10
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 2 is deciding whether to pass or bid. Current bid is 8 for Athlete(mean=23.760040851998838, variance=2.527869205937997, position=Position.DEFENSEMAN)
# This player is ranked 10
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 3 is deciding whether to pass or bid. Current bid is 9 for Athlete(mean=23.760040851998838, variance=2.527869205937997, position=Position.DEFENSEMAN)
# This player is ranked 10
# PROPORTIONAL STRAT
# Decision: bid
# 4 is deciding whether to pass or bid. Current bid is 10 for Athlete(mean=23.760040851998838, variance=2.527869205937997, position=Position.DEFENSEMAN)
# This player is ranked 10
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 2 is deciding whether to pass or bid. Current bid is 11 for Athlete(mean=23.760040851998838, variance=2.527869205937997, position=Position.DEFENSEMAN)
# This player is ranked 10
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 3 is deciding whether to pass or bid. Current bid is 12 for Athlete(mean=23.760040851998838, variance=2.527869205937997, position=Position.DEFENSEMAN)
# This player is ranked 10
# PROPORTIONAL STRAT
# Decision: bid
# 4 is deciding whether to pass or bid. Current bid is 13 for Athlete(mean=23.760040851998838, variance=2.527869205937997, position=Position.DEFENSEMAN)
# This player is ranked 10
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 2 is deciding whether to pass or bid. Current bid is 14 for Athlete(mean=23.760040851998838, variance=2.527869205937997, position=Position.DEFENSEMAN)
# This player is ranked 10
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 3 is deciding whether to pass or bid. Current bid is 15 for Athlete(mean=23.760040851998838, variance=2.527869205937997, position=Position.DEFENSEMAN)
# This player is ranked 10
# PROPORTIONAL STRAT
# Decision: bid
# 4 is deciding whether to pass or bid. Current bid is 16 for Athlete(mean=23.760040851998838, variance=2.527869205937997, position=Position.DEFENSEMAN)
# This player is ranked 10
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 2 is deciding whether to pass or bid. Current bid is 17 for Athlete(mean=23.760040851998838, variance=2.527869205937997, position=Position.DEFENSEMAN)
# This player is ranked 10
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 3 is deciding whether to pass or bid. Current bid is 18 for Athlete(mean=23.760040851998838, variance=2.527869205937997, position=Position.DEFENSEMAN)
# This player is ranked 10
# PROPORTIONAL STRAT
# Decision: bid
# 4 is deciding whether to pass or bid. Current bid is 19 for Athlete(mean=23.760040851998838, variance=2.527869205937997, position=Position.DEFENSEMAN)
# This player is ranked 10
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 2 is deciding whether to pass or bid. Current bid is 20 for Athlete(mean=23.760040851998838, variance=2.527869205937997, position=Position.DEFENSEMAN)
# This player is ranked 10
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 3 is deciding whether to pass or bid. Current bid is 21 for Athlete(mean=23.760040851998838, variance=2.527869205937997, position=Position.DEFENSEMAN)
# This player is ranked 10
# PROPORTIONAL STRAT
# Decision: pass
# 4 is deciding whether to pass or bid. Current bid is 21 for Athlete(mean=23.760040851998838, variance=2.527869205937997, position=Position.DEFENSEMAN)
# This player is ranked 10
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 2 is deciding whether to pass or bid. Current bid is 22 for Athlete(mean=23.760040851998838, variance=2.527869205937997, position=Position.DEFENSEMAN)
# This player is ranked 10
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 4 is deciding whether to pass or bid. Current bid is 23 for Athlete(mean=23.760040851998838, variance=2.527869205937997, position=Position.DEFENSEMAN)
# This player is ranked 10
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 2 is deciding whether to pass or bid. Current bid is 24 for Athlete(mean=23.760040851998838, variance=2.527869205937997, position=Position.DEFENSEMAN)
# This player is ranked 10
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 4 is deciding whether to pass or bid. Current bid is 25 for Athlete(mean=23.760040851998838, variance=2.527869205937997, position=Position.DEFENSEMAN)
# This player is ranked 10
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 2 is deciding whether to pass or bid. Current bid is 26 for Athlete(mean=23.760040851998838, variance=2.527869205937997, position=Position.DEFENSEMAN)
# This player is ranked 10
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 4 is deciding whether to pass or bid. Current bid is 27 for Athlete(mean=23.760040851998838, variance=2.527869205937997, position=Position.DEFENSEMAN)
# This player is ranked 10
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 2 is deciding whether to pass or bid. Current bid is 28 for Athlete(mean=23.760040851998838, variance=2.527869205937997, position=Position.DEFENSEMAN)
# This player is ranked 10
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 4 is deciding whether to pass or bid. Current bid is 29 for Athlete(mean=23.760040851998838, variance=2.527869205937997, position=Position.DEFENSEMAN)
# This player is ranked 10
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 2 is deciding whether to pass or bid. Current bid is 30 for Athlete(mean=23.760040851998838, variance=2.527869205937997, position=Position.DEFENSEMAN)
# This player is ranked 10
# VALUE ABOVE REPLACEMENT STRAT
# Decision: pass
# 3 is deciding whether to pass or bid. Current bid is 0 for Athlete(mean=38.34789302510171, variance=4.0445231572586025, position=Position.FORWARD)
# This player is ranked 30
# PROPORTIONAL STRAT
# Decision: pass
# 4 is deciding whether to pass or bid. Current bid is 0 for Athlete(mean=38.34789302510171, variance=4.0445231572586025, position=Position.FORWARD)
# This player is ranked 30
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 5 is deciding whether to pass or bid. Current bid is 1 for Athlete(mean=38.34789302510171, variance=4.0445231572586025, position=Position.FORWARD)
# This player is ranked 30
# PROPORTIONAL STRAT
# Decision: bid
# 0 is deciding whether to pass or bid. Current bid is 2 for Athlete(mean=38.34789302510171, variance=4.0445231572586025, position=Position.FORWARD)
# This player is ranked 30
# MONTE CARLO STRAT
# Action: pass, Score: 3.641274647887324
# Action: bid, Score: 3.7308489436619716
# Decision: bid
# 1 is deciding whether to pass or bid. Current bid is 3 for Athlete(mean=38.34789302510171, variance=4.0445231572586025, position=Position.FORWARD)
# This player is ranked 30
# MONTE CARLO STRAT
# Action: pass, Score: 3.30973956043956
# Action: bid, Score: 3.3109351648351644
# Decision: bid
# 2 is deciding whether to pass or bid. Current bid is 4 for Athlete(mean=38.34789302510171, variance=4.0445231572586025, position=Position.FORWARD)
# This player is ranked 30
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 4 is deciding whether to pass or bid. Current bid is 5 for Athlete(mean=38.34789302510171, variance=4.0445231572586025, position=Position.FORWARD)
# This player is ranked 30
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 5 is deciding whether to pass or bid. Current bid is 6 for Athlete(mean=38.34789302510171, variance=4.0445231572586025, position=Position.FORWARD)
# This player is ranked 30
# PROPORTIONAL STRAT
# Decision: pass
# 0 is deciding whether to pass or bid. Current bid is 6 for Athlete(mean=38.34789302510171, variance=4.0445231572586025, position=Position.FORWARD)
# This player is ranked 30
# MONTE CARLO STRAT
# Action: pass, Score: 3.6948940140845075
# Action: bid, Score: 3.3583514084507047
# Decision: pass
# 1 is deciding whether to pass or bid. Current bid is 6 for Athlete(mean=38.34789302510171, variance=4.0445231572586025, position=Position.FORWARD)
# This player is ranked 30
# MONTE CARLO STRAT
# Action: pass, Score: 3.3666593406593406
# Action: bid, Score: 3.386757417582417
# Decision: bid
# 2 is deciding whether to pass or bid. Current bid is 7 for Athlete(mean=38.34789302510171, variance=4.0445231572586025, position=Position.FORWARD)
# This player is ranked 30
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 4 is deciding whether to pass or bid. Current bid is 8 for Athlete(mean=38.34789302510171, variance=4.0445231572586025, position=Position.FORWARD)
# This player is ranked 30
# VALUE ABOVE REPLACEMENT STRAT
# Decision: pass
# 1 is deciding whether to pass or bid. Current bid is 8 for Athlete(mean=38.34789302510171, variance=4.0445231572586025, position=Position.FORWARD)
# This player is ranked 30
# MONTE CARLO STRAT
# Action: pass, Score: 3.3808521978021977
# Action: bid, Score: 3.2995739010989005
# Decision: pass
# 2 is deciding whether to pass or bid. Current bid is 0 for Athlete(mean=47.32944706725838, variance=4.751790363451515, position=Position.FORWARD)
# This player is ranked 20
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 3 is deciding whether to pass or bid. Current bid is 1 for Athlete(mean=47.32944706725838, variance=4.751790363451515, position=Position.FORWARD)
# This player is ranked 20
# PROPORTIONAL STRAT
# Decision: pass
# 4 is deciding whether to pass or bid. Current bid is 1 for Athlete(mean=47.32944706725838, variance=4.751790363451515, position=Position.FORWARD)
# This player is ranked 20
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 5 is deciding whether to pass or bid. Current bid is 2 for Athlete(mean=47.32944706725838, variance=4.751790363451515, position=Position.FORWARD)
# This player is ranked 20
# PROPORTIONAL STRAT
# Decision: bid
# 0 is deciding whether to pass or bid. Current bid is 3 for Athlete(mean=47.32944706725838, variance=4.751790363451515, position=Position.FORWARD)
# This player is ranked 20
# MONTE CARLO STRAT
# Action: pass, Score: 3.5543073943661976
# Action: bid, Score: 3.6312278169014087
# Decision: bid
# 1 is deciding whether to pass or bid. Current bid is 4 for Athlete(mean=47.32944706725838, variance=4.751790363451515, position=Position.FORWARD)
# This player is ranked 20
# MONTE CARLO STRAT
# Action: pass, Score: 3.472374175824176
# Action: bid, Score: 3.5078967032967037
# Decision: bid
# 2 is deciding whether to pass or bid. Current bid is 5 for Athlete(mean=47.32944706725838, variance=4.751790363451515, position=Position.FORWARD)
# This player is ranked 20
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 4 is deciding whether to pass or bid. Current bid is 6 for Athlete(mean=47.32944706725838, variance=4.751790363451515, position=Position.FORWARD)
# This player is ranked 20
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 5 is deciding whether to pass or bid. Current bid is 7 for Athlete(mean=47.32944706725838, variance=4.751790363451515, position=Position.FORWARD)
# This player is ranked 20
# PROPORTIONAL STRAT
# Decision: bid
# 0 is deciding whether to pass or bid. Current bid is 8 for Athlete(mean=47.32944706725838, variance=4.751790363451515, position=Position.FORWARD)
# This player is ranked 20
# MONTE CARLO STRAT
# Action: pass, Score: 3.6840239436619724
# Action: bid, Score: 3.6468883802816903
# Decision: pass
# 1 is deciding whether to pass or bid. Current bid is 8 for Athlete(mean=47.32944706725838, variance=4.751790363451515, position=Position.FORWARD)
# This player is ranked 20
# MONTE CARLO STRAT
# Action: pass, Score: 3.3915552197802192
# Action: bid, Score: 3.1339043956043957
# Decision: pass
# 2 is deciding whether to pass or bid. Current bid is 8 for Athlete(mean=47.32944706725838, variance=4.751790363451515, position=Position.FORWARD)
# This player is ranked 20
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 4 is deciding whether to pass or bid. Current bid is 9 for Athlete(mean=47.32944706725838, variance=4.751790363451515, position=Position.FORWARD)
# This player is ranked 20
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 5 is deciding whether to pass or bid. Current bid is 10 for Athlete(mean=47.32944706725838, variance=4.751790363451515, position=Position.FORWARD)
# This player is ranked 20
# PROPORTIONAL STRAT
# Decision: pass
# 2 is deciding whether to pass or bid. Current bid is 10 for Athlete(mean=47.32944706725838, variance=4.751790363451515, position=Position.FORWARD)
# This player is ranked 20
# VALUE ABOVE REPLACEMENT STRAT
# Decision: pass
# 3 is deciding whether to pass or bid. Current bid is 0 for Athlete(mean=21.743018686235665, variance=3.1128058354027663, position=Position.FORWARD)
# This player is ranked 42
# PROPORTIONAL STRAT
# Decision: pass
# 4 is deciding whether to pass or bid. Current bid is 0 for Athlete(mean=21.743018686235665, variance=3.1128058354027663, position=Position.FORWARD)
# This player is ranked 42
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 5 is deciding whether to pass or bid. Current bid is 1 for Athlete(mean=21.743018686235665, variance=3.1128058354027663, position=Position.FORWARD)
# This player is ranked 42
# PROPORTIONAL STRAT
# Decision: bid
# 0 is deciding whether to pass or bid. Current bid is 2 for Athlete(mean=21.743018686235665, variance=3.1128058354027663, position=Position.FORWARD)
# This player is ranked 42
# MONTE CARLO STRAT
# Action: pass, Score: 3.754367605633803
# Action: bid, Score: 3.5755612676056336
# Decision: pass
# 1 is deciding whether to pass or bid. Current bid is 2 for Athlete(mean=21.743018686235665, variance=3.1128058354027663, position=Position.FORWARD)
# This player is ranked 42
# MONTE CARLO STRAT
# Action: pass, Score: 3.55446923076923
# Action: bid, Score: 3.3890686813186814
# Decision: pass
# 2 is deciding whether to pass or bid. Current bid is 2 for Athlete(mean=21.743018686235665, variance=3.1128058354027663, position=Position.FORWARD)
# This player is ranked 42
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 4 is deciding whether to pass or bid. Current bid is 3 for Athlete(mean=21.743018686235665, variance=3.1128058354027663, position=Position.FORWARD)
# This player is ranked 42
# VALUE ABOVE REPLACEMENT STRAT
# Decision: pass
# 5 is deciding whether to pass or bid. Current bid is 3 for Athlete(mean=21.743018686235665, variance=3.1128058354027663, position=Position.FORWARD)
# This player is ranked 42
# PROPORTIONAL STRAT
# Decision: pass
# 0 is deciding whether to pass or bid. Current bid is 0 for Athlete(mean=92.15701069339684, variance=9.455290838437941, position=Position.FORWARD)
# This player is ranked 5
# MONTE CARLO STRAT
# Action: pass, Score: 3.5230700704225355
# Action: bid, Score: 3.7651968309859156
# Decision: bid
# 1 is deciding whether to pass or bid. Current bid is 1 for Athlete(mean=92.15701069339684, variance=9.455290838437941, position=Position.FORWARD)
# This player is ranked 5
# MONTE CARLO STRAT
# Action: pass, Score: 3.4372664835164835
# Action: bid, Score: 3.46057032967033
# Decision: bid
# 2 is deciding whether to pass or bid. Current bid is 2 for Athlete(mean=92.15701069339684, variance=9.455290838437941, position=Position.FORWARD)
# This player is ranked 5
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 3 is deciding whether to pass or bid. Current bid is 3 for Athlete(mean=92.15701069339684, variance=9.455290838437941, position=Position.FORWARD)
# This player is ranked 5
# PROPORTIONAL STRAT
# Decision: pass
# 4 is deciding whether to pass or bid. Current bid is 3 for Athlete(mean=92.15701069339684, variance=9.455290838437941, position=Position.FORWARD)
# This player is ranked 5
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 5 is deciding whether to pass or bid. Current bid is 4 for Athlete(mean=92.15701069339684, variance=9.455290838437941, position=Position.FORWARD)
# This player is ranked 5
# PROPORTIONAL STRAT
# Decision: bid
# 0 is deciding whether to pass or bid. Current bid is 5 for Athlete(mean=92.15701069339684, variance=9.455290838437941, position=Position.FORWARD)
# This player is ranked 5
# MONTE CARLO STRAT
# Action: pass, Score: 3.5054521126760565
# Action: bid, Score: 3.7303292253521128
# Decision: bid
# 1 is deciding whether to pass or bid. Current bid is 6 for Athlete(mean=92.15701069339684, variance=9.455290838437941, position=Position.FORWARD)
# This player is ranked 5
# MONTE CARLO STRAT
# Action: pass, Score: 3.44670054945055
# Action: bid, Score: 3.5825631868131875
# Decision: bid
# 2 is deciding whether to pass or bid. Current bid is 7 for Athlete(mean=92.15701069339684, variance=9.455290838437941, position=Position.FORWARD)
# This player is ranked 5
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 4 is deciding whether to pass or bid. Current bid is 8 for Athlete(mean=92.15701069339684, variance=9.455290838437941, position=Position.FORWARD)
# This player is ranked 5
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 5 is deciding whether to pass or bid. Current bid is 9 for Athlete(mean=92.15701069339684, variance=9.455290838437941, position=Position.FORWARD)
# This player is ranked 5
# PROPORTIONAL STRAT
# Decision: bid
# 0 is deciding whether to pass or bid. Current bid is 10 for Athlete(mean=92.15701069339684, variance=9.455290838437941, position=Position.FORWARD)
# This player is ranked 5
# MONTE CARLO STRAT
# Action: pass, Score: 3.7983151408450704
# Action: bid, Score: 3.850345422535211
# Decision: bid
# 1 is deciding whether to pass or bid. Current bid is 11 for Athlete(mean=92.15701069339684, variance=9.455290838437941, position=Position.FORWARD)
# This player is ranked 5
# MONTE CARLO STRAT
# Action: pass, Score: 3.3537118131868136
# Action: bid, Score: 3.6276774725274725
# Decision: bid
# 2 is deciding whether to pass or bid. Current bid is 12 for Athlete(mean=92.15701069339684, variance=9.455290838437941, position=Position.FORWARD)
# This player is ranked 5
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 4 is deciding whether to pass or bid. Current bid is 13 for Athlete(mean=92.15701069339684, variance=9.455290838437941, position=Position.FORWARD)
# This player is ranked 5
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 5 is deciding whether to pass or bid. Current bid is 14 for Athlete(mean=92.15701069339684, variance=9.455290838437941, position=Position.FORWARD)
# This player is ranked 5
# PROPORTIONAL STRAT
# Decision: bid
# 0 is deciding whether to pass or bid. Current bid is 15 for Athlete(mean=92.15701069339684, variance=9.455290838437941, position=Position.FORWARD)
# This player is ranked 5
# MONTE CARLO STRAT
# Action: pass, Score: 3.743982394366197
# Action: bid, Score: 3.967275
# Decision: bid
# 1 is deciding whether to pass or bid. Current bid is 16 for Athlete(mean=92.15701069339684, variance=9.455290838437941, position=Position.FORWARD)
# This player is ranked 5
# MONTE CARLO STRAT
# Action: pass, Score: 3.3876612637362644
# Action: bid, Score: 3.586118956043957
# Decision: bid
# 2 is deciding whether to pass or bid. Current bid is 17 for Athlete(mean=92.15701069339684, variance=9.455290838437941, position=Position.FORWARD)
# This player is ranked 5
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 4 is deciding whether to pass or bid. Current bid is 18 for Athlete(mean=92.15701069339684, variance=9.455290838437941, position=Position.FORWARD)
# This player is ranked 5
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 5 is deciding whether to pass or bid. Current bid is 19 for Athlete(mean=92.15701069339684, variance=9.455290838437941, position=Position.FORWARD)
# This player is ranked 5
# PROPORTIONAL STRAT
# Decision: pass
# 0 is deciding whether to pass or bid. Current bid is 19 for Athlete(mean=92.15701069339684, variance=9.455290838437941, position=Position.FORWARD)
# This player is ranked 5
# MONTE CARLO STRAT
# Action: pass, Score: 3.680547887323944
# Action: bid, Score: 3.7545845070422534
# Decision: bid
# 1 is deciding whether to pass or bid. Current bid is 20 for Athlete(mean=92.15701069339684, variance=9.455290838437941, position=Position.FORWARD)
# This player is ranked 5
# MONTE CARLO STRAT
# Action: pass, Score: 3.5668480769230766
# Action: bid, Score: 3.6285208791208783
# Decision: bid
# 2 is deciding whether to pass or bid. Current bid is 21 for Athlete(mean=92.15701069339684, variance=9.455290838437941, position=Position.FORWARD)
# This player is ranked 5
# VALUE ABOVE REPLACEMENT STRAT
# Decision: pass
# 4 is deciding whether to pass or bid. Current bid is 21 for Athlete(mean=92.15701069339684, variance=9.455290838437941, position=Position.FORWARD)
# This player is ranked 5
# VALUE ABOVE REPLACEMENT STRAT
# Decision: pass
# 0 is deciding whether to pass or bid. Current bid is 21 for Athlete(mean=92.15701069339684, variance=9.455290838437941, position=Position.FORWARD)
# This player is ranked 5
# MONTE CARLO STRAT
# Action: pass, Score: 3.608797535211267
# Action: bid, Score: 4.047967253521127
# Decision: bid
# 1 is deciding whether to pass or bid. Current bid is 22 for Athlete(mean=92.15701069339684, variance=9.455290838437941, position=Position.FORWARD)
# This player is ranked 5
# MONTE CARLO STRAT
# Action: pass, Score: 3.325646428571429
# Action: bid, Score: 3.787593956043956
# Decision: bid
# 0 is deciding whether to pass or bid. Current bid is 23 for Athlete(mean=92.15701069339684, variance=9.455290838437941, position=Position.FORWARD)
# This player is ranked 5
# MONTE CARLO STRAT
# Action: pass, Score: 3.5292873239436626
# Action: bid, Score: 4.005731690140846
# Decision: bid
# 1 is deciding whether to pass or bid. Current bid is 24 for Athlete(mean=92.15701069339684, variance=9.455290838437941, position=Position.FORWARD)
# This player is ranked 5
# MONTE CARLO STRAT
# Action: pass, Score: 3.4058497252747246
# Action: bid, Score: 3.8462815934065935
# Decision: bid
# 0 is deciding whether to pass or bid. Current bid is 25 for Athlete(mean=92.15701069339684, variance=9.455290838437941, position=Position.FORWARD)
# This player is ranked 5
# MONTE CARLO STRAT
# Action: pass, Score: 3.586483450704225
# Action: bid, Score: 3.997287323943662
# Decision: bid
# 1 is deciding whether to pass or bid. Current bid is 26 for Athlete(mean=92.15701069339684, variance=9.455290838437941, position=Position.FORWARD)
# This player is ranked 5
# MONTE CARLO STRAT
# Action: pass, Score: 3.5093497252747254
# Action: bid, Score: 3.744246978021979
# Decision: bid
# 0 is deciding whether to pass or bid. Current bid is 27 for Athlete(mean=92.15701069339684, variance=9.455290838437941, position=Position.FORWARD)
# This player is ranked 5
# MONTE CARLO STRAT
# Action: pass, Score: 3.510295774647887
# Action: bid, Score: 4.037539436619719
# Decision: bid
# 1 is deciding whether to pass or bid. Current bid is 28 for Athlete(mean=92.15701069339684, variance=9.455290838437941, position=Position.FORWARD)
# This player is ranked 5
# MONTE CARLO STRAT
# Action: pass, Score: 3.3954651098901096
# Action: bid, Score: 3.817558791208791
# Decision: bid
# 0 is deciding whether to pass or bid. Current bid is 29 for Athlete(mean=92.15701069339684, variance=9.455290838437941, position=Position.FORWARD)
# This player is ranked 5
# MONTE CARLO STRAT
# Action: pass, Score: 3.5564679577464786
# Action: bid, Score: 3.84972323943662
# Decision: bid
# 1 is deciding whether to pass or bid. Current bid is 30 for Athlete(mean=92.15701069339684, variance=9.455290838437941, position=Position.FORWARD)
# This player is ranked 5
# MONTE CARLO STRAT
# Action: pass, Score: 3.463182692307693
# Action: bid, Score: 3.7319862637362635
# Decision: bid
# 0 is deciding whether to pass or bid. Current bid is 31 for Athlete(mean=92.15701069339684, variance=9.455290838437941, position=Position.FORWARD)
# This player is ranked 5
# MONTE CARLO STRAT
# Action: pass, Score: 3.6369084507042255
# Action: bid, Score: 3.9538605633802812
# Decision: bid
# 1 is deciding whether to pass or bid. Current bid is 32 for Athlete(mean=92.15701069339684, variance=9.455290838437941, position=Position.FORWARD)
# This player is ranked 5
# MONTE CARLO STRAT
# Action: pass, Score: 3.3008175824175816
# Action: bid, Score: 3.7961142857142858
# Decision: bid
# 0 is deciding whether to pass or bid. Current bid is 33 for Athlete(mean=92.15701069339684, variance=9.455290838437941, position=Position.FORWARD)
# This player is ranked 5
# MONTE CARLO STRAT
# Action: pass, Score: 3.5191105633802824
# Action: bid, Score: 4.031773591549295
# Decision: bid
# 1 is deciding whether to pass or bid. Current bid is 34 for Athlete(mean=92.15701069339684, variance=9.455290838437941, position=Position.FORWARD)
# This player is ranked 5
# MONTE CARLO STRAT
# Action: pass, Score: 3.4439497252747246
# Action: bid, Score: 3.765404395604395
# Decision: bid
# 0 is deciding whether to pass or bid. Current bid is 35 for Athlete(mean=92.15701069339684, variance=9.455290838437941, position=Position.FORWARD)
# This player is ranked 5
# MONTE CARLO STRAT
# Action: pass, Score: 3.8334140845070426
# Action: bid, Score: 3.849009507042254
# Decision: bid
# 1 is deciding whether to pass or bid. Current bid is 36 for Athlete(mean=92.15701069339684, variance=9.455290838437941, position=Position.FORWARD)
# This player is ranked 5
# MONTE CARLO STRAT
# Action: pass, Score: 3.26653543956044
# Action: bid, Score: 3.7201271978021984
# Decision: bid
# 0 is deciding whether to pass or bid. Current bid is 37 for Athlete(mean=92.15701069339684, variance=9.455290838437941, position=Position.FORWARD)
# This player is ranked 5
# MONTE CARLO STRAT
# Action: pass, Score: 3.6193080985915493
# Action: bid, Score: 3.9791419014084504
# Decision: bid
# 1 is deciding whether to pass or bid. Current bid is 38 for Athlete(mean=92.15701069339684, variance=9.455290838437941, position=Position.FORWARD)
# This player is ranked 5
# MONTE CARLO STRAT
# Action: pass, Score: 3.3992417582417582
# Action: bid, Score: 3.753048626373627
# Decision: bid
# 0 is deciding whether to pass or bid. Current bid is 39 for Athlete(mean=92.15701069339684, variance=9.455290838437941, position=Position.FORWARD)
# This player is ranked 5
# MONTE CARLO STRAT
# Action: pass, Score: 3.6711577464788725
# Action: bid, Score: 3.6775306338028164
# Decision: bid
# 1 is deciding whether to pass or bid. Current bid is 40 for Athlete(mean=92.15701069339684, variance=9.455290838437941, position=Position.FORWARD)
# This player is ranked 5
# MONTE CARLO STRAT
# Action: pass, Score: 3.463461813186813
# Action: bid, Score: 3.655595054945056
# Decision: bid
# 0 is deciding whether to pass or bid. Current bid is 41 for Athlete(mean=92.15701069339684, variance=9.455290838437941, position=Position.FORWARD)
# This player is ranked 5
# MONTE CARLO STRAT
# Action: pass, Score: 3.455342957746479
# Action: bid, Score: 3.9371894366197187
# Decision: bid
# 1 is deciding whether to pass or bid. Current bid is 42 for Athlete(mean=92.15701069339684, variance=9.455290838437941, position=Position.FORWARD)
# This player is ranked 5
# MONTE CARLO STRAT
# Action: pass, Score: 3.383713736263737
# Action: bid, Score: 3.655343681318682
# Decision: bid
# 0 is deciding whether to pass or bid. Current bid is 43 for Athlete(mean=92.15701069339684, variance=9.455290838437941, position=Position.FORWARD)
# This player is ranked 5
# MONTE CARLO STRAT
# Action: pass, Score: 3.578736267605634
# Action: bid, Score: 3.632828873239437
# Decision: bid
# 1 is deciding whether to pass or bid. Current bid is 44 for Athlete(mean=92.15701069339684, variance=9.455290838437941, position=Position.FORWARD)
# This player is ranked 5
# MONTE CARLO STRAT
# Action: pass, Score: 3.535706593406594
# Action: bid, Score: 3.6381079670329664
# Decision: bid
# 0 is deciding whether to pass or bid. Current bid is 45 for Athlete(mean=92.15701069339684, variance=9.455290838437941, position=Position.FORWARD)
# This player is ranked 5
# MONTE CARLO STRAT
# Action: pass, Score: 3.688889084507042
# Action: bid, Score: 3.9532084507042256
# Decision: bid
# 1 is deciding whether to pass or bid. Current bid is 46 for Athlete(mean=92.15701069339684, variance=9.455290838437941, position=Position.FORWARD)
# This player is ranked 5
# MONTE CARLO STRAT
# Action: pass, Score: 3.485916208791209
# Action: bid, Score: 3.582395604395604
# Decision: bid
# 0 is deciding whether to pass or bid. Current bid is 47 for Athlete(mean=92.15701069339684, variance=9.455290838437941, position=Position.FORWARD)
# This player is ranked 5
# MONTE CARLO STRAT
# Action: pass, Score: 3.5931063380281687
# Action: bid, Score: 3.735999647887324
# Decision: bid
# 1 is deciding whether to pass or bid. Current bid is 48 for Athlete(mean=92.15701069339684, variance=9.455290838437941, position=Position.FORWARD)
# This player is ranked 5
# MONTE CARLO STRAT
# Action: pass, Score: 3.4070175824175832
# Action: bid, Score: 3.5347769230769233
# Decision: bid
# 0 is deciding whether to pass or bid. Current bid is 49 for Athlete(mean=92.15701069339684, variance=9.455290838437941, position=Position.FORWARD)
# This player is ranked 5
# MONTE CARLO STRAT
# Action: pass, Score: 3.6536253521126763
# Action: bid, Score: 3.4443795774647894
# Decision: pass
# 1 is deciding whether to pass or bid. Current bid is 0 for Athlete(mean=11.967194375443045, variance=2.0845372904797097, position=Position.FORWARD)
# This player is ranked 47
# MONTE CARLO STRAT
# Action: pass, Score: 3.6379252747252746
# Action: bid, Score: 3.4861673076923068
# Decision: pass
# 2 is deciding whether to pass or bid. Current bid is 0 for Athlete(mean=11.967194375443045, variance=2.0845372904797097, position=Position.FORWARD)
# This player is ranked 47
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 3 is deciding whether to pass or bid. Current bid is 1 for Athlete(mean=11.967194375443045, variance=2.0845372904797097, position=Position.FORWARD)
# This player is ranked 47
# PROPORTIONAL STRAT
# Decision: pass
# 4 is deciding whether to pass or bid. Current bid is 1 for Athlete(mean=11.967194375443045, variance=2.0845372904797097, position=Position.FORWARD)
# This player is ranked 47
# VALUE ABOVE REPLACEMENT STRAT
# Decision: pass
# 5 is deciding whether to pass or bid. Current bid is 1 for Athlete(mean=11.967194375443045, variance=2.0845372904797097, position=Position.FORWARD)
# This player is ranked 47
# PROPORTIONAL STRAT
# Decision: bid
# 0 is deciding whether to pass or bid. Current bid is 2 for Athlete(mean=11.967194375443045, variance=2.0845372904797097, position=Position.FORWARD)
# This player is ranked 47
# MONTE CARLO STRAT
# Action: pass, Score: 3.862242605633803
# Action: bid, Score: 3.5022489436619715
# Decision: pass
# 2 is deciding whether to pass or bid. Current bid is 2 for Athlete(mean=11.967194375443045, variance=2.0845372904797097, position=Position.FORWARD)
# This player is ranked 47
# VALUE ABOVE REPLACEMENT STRAT
# Decision: pass
# 3 is deciding whether to pass or bid. Current bid is 0 for Athlete(mean=39.972059623798856, variance=4.0525884745033585, position=Position.FORWARD)
# This player is ranked 27
# PROPORTIONAL STRAT
# Decision: pass
# 4 is deciding whether to pass or bid. Current bid is 0 for Athlete(mean=39.972059623798856, variance=4.0525884745033585, position=Position.FORWARD)
# This player is ranked 27
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 5 is deciding whether to pass or bid. Current bid is 1 for Athlete(mean=39.972059623798856, variance=4.0525884745033585, position=Position.FORWARD)
# This player is ranked 27
# PROPORTIONAL STRAT
# Decision: bid
# 0 is deciding whether to pass or bid. Current bid is 2 for Athlete(mean=39.972059623798856, variance=4.0525884745033585, position=Position.FORWARD)
# This player is ranked 27
# MONTE CARLO STRAT
# Action: pass, Score: 4.03425633802817
# Action: bid, Score: 3.818199647887324
# Decision: pass
# 1 is deciding whether to pass or bid. Current bid is 2 for Athlete(mean=39.972059623798856, variance=4.0525884745033585, position=Position.FORWARD)
# This player is ranked 27
# MONTE CARLO STRAT
# Action: pass, Score: 3.5854950549450555
# Action: bid, Score: 3.5862923076923074
# Decision: bid
# 2 is deciding whether to pass or bid. Current bid is 3 for Athlete(mean=39.972059623798856, variance=4.0525884745033585, position=Position.FORWARD)
# This player is ranked 27
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 4 is deciding whether to pass or bid. Current bid is 4 for Athlete(mean=39.972059623798856, variance=4.0525884745033585, position=Position.FORWARD)
# This player is ranked 27
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 5 is deciding whether to pass or bid. Current bid is 5 for Athlete(mean=39.972059623798856, variance=4.0525884745033585, position=Position.FORWARD)
# This player is ranked 27
# PROPORTIONAL STRAT
# Decision: bid
# 1 is deciding whether to pass or bid. Current bid is 6 for Athlete(mean=39.972059623798856, variance=4.0525884745033585, position=Position.FORWARD)
# This player is ranked 27
# ...
# This player is ranked 5
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 0 is deciding whether to pass or bid. Current bid is 7 for Athlete(mean=79.34085120812811, variance=9.131944497523785, position=Position.FORWARD)
# This player is ranked 5
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 1 is deciding whether to pass or bid. Current bid is 8 for Athlete(mean=79.34085120812811, variance=9.131944497523785, position=Position.FORWARD)
# This player is ranked 5
# MONTE CARLO STRAT
# Action: pass, Score: 4.376316150442479
# Action: bid, Score: 4.390269247787611
# Decision: bid
# 3 is deciding whether to pass or bid. Current bid is 9 for Athlete(mean=79.34085120812811, variance=9.131944497523785, position=Position.FORWARD)
# This player is ranked 5
# MONTE CARLO STRAT
# Action: pass, Score: 5.030974444444444
# Action: bid, Score: 5.103777407407409
# Decision: bid
# 4 is deciding whether to pass or bid. Current bid is 10 for Athlete(mean=79.34085120812811, variance=9.131944497523785, position=Position.FORWARD)
# This player is ranked 5
# MONTE CARLO STRAT
# Action: pass, Score: 4.6315880952380954
# Action: bid, Score: 4.709751488095238
# Decision: bid
# 5 is deciding whether to pass or bid. Current bid is 11 for Athlete(mean=79.34085120812811, variance=9.131944497523785, position=Position.FORWARD)
# This player is ranked 5
# VALUE ABOVE REPLACEMENT STRAT
# Decision: pass
# 0 is deciding whether to pass or bid. Current bid is 11 for Athlete(mean=79.34085120812811, variance=9.131944497523785, position=Position.FORWARD)
# This player is ranked 5
# VALUE ABOVE REPLACEMENT STRAT
# Decision: pass
# 1 is deciding whether to pass or bid. Current bid is 11 for Athlete(mean=79.34085120812811, variance=9.131944497523785, position=Position.FORWARD)
# This player is ranked 5
# MONTE CARLO STRAT
# Action: pass, Score: 4.184348008849558
# Action: bid, Score: 4.27033075221239
# Decision: bid
# 3 is deciding whether to pass or bid. Current bid is 12 for Athlete(mean=79.34085120812811, variance=9.131944497523785, position=Position.FORWARD)
# This player is ranked 5
# MONTE CARLO STRAT
# Action: pass, Score: 5.014405555555555
# Action: bid, Score: 5.098123148148148
# Decision: bid
# 4 is deciding whether to pass or bid. Current bid is 13 for Athlete(mean=79.34085120812811, variance=9.131944497523785, position=Position.FORWARD)
# This player is ranked 5
# MONTE CARLO STRAT
# Action: pass, Score: 4.669687499999999
# Action: bid, Score: 4.534693154761904
# Decision: pass
# 1 is deciding whether to pass or bid. Current bid is 13 for Athlete(mean=79.34085120812811, variance=9.131944497523785, position=Position.FORWARD)
# This player is ranked 5
# MONTE CARLO STRAT
# Action: pass, Score: 4.141071017699115
# Action: bid, Score: 4.427829646017699
# Decision: bid
# 3 is deciding whether to pass or bid. Current bid is 14 for Athlete(mean=79.34085120812811, variance=9.131944497523785, position=Position.FORWARD)
# This player is ranked 5
# MONTE CARLO STRAT
# Action: pass, Score: 4.981364814814816
# Action: bid, Score: 5.006601296296296
# Decision: bid
# 1 is deciding whether to pass or bid. Current bid is 15 for Athlete(mean=79.34085120812811, variance=9.131944497523785, position=Position.FORWARD)
# This player is ranked 5
# MONTE CARLO STRAT
# Action: pass, Score: 4.170374336283187
# Action: bid, Score: 4.406707522123894
# Decision: bid
# 3 is deciding whether to pass or bid. Current bid is 16 for Athlete(mean=79.34085120812811, variance=9.131944497523785, position=Position.FORWARD)
# This player is ranked 5
# MONTE CARLO STRAT
# Action: pass, Score: 5.030141111111112
# Action: bid, Score: 5.001128518518519
# Decision: pass
# 4 is deciding whether to pass or bid. Current bid is 0 for Athlete(mean=55.29156749377318, variance=5.576493932102694, position=Position.FORWARD)
# This player is ranked 15
# MONTE CARLO STRAT
# Action: pass, Score: 4.52575863095238
# Action: bid, Score: 4.5082482142857145
# Decision: pass
# 5 is deciding whether to pass or bid. Current bid is 0 for Athlete(mean=55.29156749377318, variance=5.576493932102694, position=Position.FORWARD)
# This player is ranked 15
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 0 is deciding whether to pass or bid. Current bid is 1 for Athlete(mean=55.29156749377318, variance=5.576493932102694, position=Position.FORWARD)
# This player is ranked 15
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 1 is deciding whether to pass or bid. Current bid is 2 for Athlete(mean=55.29156749377318, variance=5.576493932102694, position=Position.FORWARD)
# This player is ranked 15
# MONTE CARLO STRAT
# Action: pass, Score: 4.429604424778763
# Action: bid, Score: 4.6519508849557525
# Decision: bid
# 2 is deciding whether to pass or bid. Current bid is 3 for Athlete(mean=55.29156749377318, variance=5.576493932102694, position=Position.FORWARD)
# This player is ranked 15
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 3 is deciding whether to pass or bid. Current bid is 3 for Athlete(mean=55.29156749377318, variance=5.576493932102694, position=Position.FORWARD)
# This player is ranked 15
# MONTE CARLO STRAT
# Action: pass, Score: 5.0547894444444434
# Action: bid, Score: 4.978448333333334
# Decision: pass
# 5 is deciding whether to pass or bid. Current bid is 3 for Athlete(mean=55.29156749377318, variance=5.576493932102694, position=Position.FORWARD)
# This player is ranked 15
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 0 is deciding whether to pass or bid. Current bid is 4 for Athlete(mean=55.29156749377318, variance=5.576493932102694, position=Position.FORWARD)
# This player is ranked 15
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 1 is deciding whether to pass or bid. Current bid is 5 for Athlete(mean=55.29156749377318, variance=5.576493932102694, position=Position.FORWARD)
# This player is ranked 15
# MONTE CARLO STRAT
# Action: pass, Score: 4.594366150442479
# Action: bid, Score: 4.541760398230088
# Decision: pass
# 5 is deciding whether to pass or bid. Current bid is 5 for Athlete(mean=55.29156749377318, variance=5.576493932102694, position=Position.FORWARD)
# This player is ranked 15
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 0 is deciding whether to pass or bid. Current bid is 6 for Athlete(mean=55.29156749377318, variance=5.576493932102694, position=Position.FORWARD)
# This player is ranked 15
# VALUE ABOVE REPLACEMENT STRAT
# Decision: pass
# 1 is deciding whether to pass or bid. Current bid is 0 for Athlete(mean=19.092453700494506, variance=9.706966478491317, position=Position.FORWARD)
# This player is ranked 43
# MONTE CARLO STRAT
# Action: pass, Score: 4.610865929203539
# Action: bid, Score: 4.607754424778761
# Decision: pass
# 2 is deciding whether to pass or bid. Current bid is 0 for Athlete(mean=19.092453700494506, variance=9.706966478491317, position=Position.FORWARD)
# This player is ranked 43
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 3 is deciding whether to pass or bid. Current bid is 0 for Athlete(mean=19.092453700494506, variance=9.706966478491317, position=Position.FORWARD)
# This player is ranked 43
# MONTE CARLO STRAT
# Action: pass, Score: 4.978813888888888
# Action: bid, Score: 4.960434814814816
# Decision: pass
# 4 is deciding whether to pass or bid. Current bid is 0 for Athlete(mean=19.092453700494506, variance=9.706966478491317, position=Position.FORWARD)
# This player is ranked 43
# MONTE CARLO STRAT
# Action: pass, Score: 4.636979464285715
# Action: bid, Score: 4.614791666666668
# Decision: pass
# 5 is deciding whether to pass or bid. Current bid is 0 for Athlete(mean=19.092453700494506, variance=9.706966478491317, position=Position.FORWARD)
# This player is ranked 43
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 0 is deciding whether to pass or bid. Current bid is 1 for Athlete(mean=19.092453700494506, variance=9.706966478491317, position=Position.FORWARD)
# This player is ranked 43
# VALUE ABOVE REPLACEMENT STRAT
# Decision: pass
# 1 is deciding whether to pass or bid. Current bid is 0 for Athlete(mean=138.7857982341011, variance=20.80605452375022, position=Position.FORWARD)
# This player is ranked 1
# MONTE CARLO STRAT
# Action: pass, Score: 4.404075663716814
# Action: bid, Score: 4.736702876106194
# Decision: bid
# 2 is deciding whether to pass or bid. Current bid is 1 for Athlete(mean=138.7857982341011, variance=20.80605452375022, position=Position.FORWARD)
# This player is ranked 1
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 3 is deciding whether to pass or bid. Current bid is 1 for Athlete(mean=138.7857982341011, variance=20.80605452375022, position=Position.FORWARD)
# This player is ranked 1
# MONTE CARLO STRAT
# Action: pass, Score: 4.960452962962964
# Action: bid, Score: 5.096798703703705
# Decision: bid
# 4 is deciding whether to pass or bid. Current bid is 2 for Athlete(mean=138.7857982341011, variance=20.80605452375022, position=Position.FORWARD)
# This player is ranked 1
# MONTE CARLO STRAT
# Action: pass, Score: 4.487540178571429
# Action: bid, Score: 4.643239583333333
# Decision: bid
# 5 is deciding whether to pass or bid. Current bid is 3 for Athlete(mean=138.7857982341011, variance=20.80605452375022, position=Position.FORWARD)
# This player is ranked 1
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 0 is deciding whether to pass or bid. Current bid is 4 for Athlete(mean=138.7857982341011, variance=20.80605452375022, position=Position.FORWARD)
# This player is ranked 1
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 1 is deciding whether to pass or bid. Current bid is 5 for Athlete(mean=138.7857982341011, variance=20.80605452375022, position=Position.FORWARD)
# This player is ranked 1
# MONTE CARLO STRAT
# Action: pass, Score: 4.533380973451328
# Action: bid, Score: 4.702123893805311
# Decision: bid
# 3 is deciding whether to pass or bid. Current bid is 6 for Athlete(mean=138.7857982341011, variance=20.80605452375022, position=Position.FORWARD)
# This player is ranked 1
# MONTE CARLO STRAT
# Action: pass, Score: 4.978340925925927
# Action: bid, Score: 5.068431296296296
# Decision: bid
# 4 is deciding whether to pass or bid. Current bid is 7 for Athlete(mean=138.7857982341011, variance=20.80605452375022, position=Position.FORWARD)
# This player is ranked 1
# MONTE CARLO STRAT
# Action: pass, Score: 4.460521130952381
# Action: bid, Score: 4.635608035714285
# Decision: bid
# 5 is deciding whether to pass or bid. Current bid is 8 for Athlete(mean=138.7857982341011, variance=20.80605452375022, position=Position.FORWARD)
# This player is ranked 1
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 0 is deciding whether to pass or bid. Current bid is 9 for Athlete(mean=138.7857982341011, variance=20.80605452375022, position=Position.FORWARD)
# This player is ranked 1
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 1 is deciding whether to pass or bid. Current bid is 10 for Athlete(mean=138.7857982341011, variance=20.80605452375022, position=Position.FORWARD)
# This player is ranked 1
# MONTE CARLO STRAT
# Action: pass, Score: 4.602953761061947
# Action: bid, Score: 4.674463495575223
# Decision: bid
# 3 is deciding whether to pass or bid. Current bid is 11 for Athlete(mean=138.7857982341011, variance=20.80605452375022, position=Position.FORWARD)
# This player is ranked 1
# MONTE CARLO STRAT
# Action: pass, Score: 4.974552777777778
# Action: bid, Score: 5.137689074074074
# Decision: bid
# 4 is deciding whether to pass or bid. Current bid is 12 for Athlete(mean=138.7857982341011, variance=20.80605452375022, position=Position.FORWARD)
# This player is ranked 1
# MONTE CARLO STRAT
# Action: pass, Score: 4.592255357142857
# Action: bid, Score: 4.629041964285715
# Decision: bid
# 5 is deciding whether to pass or bid. Current bid is 13 for Athlete(mean=138.7857982341011, variance=20.80605452375022, position=Position.FORWARD)
# This player is ranked 1
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 0 is deciding whether to pass or bid. Current bid is 14 for Athlete(mean=138.7857982341011, variance=20.80605452375022, position=Position.FORWARD)
# This player is ranked 1
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 1 is deciding whether to pass or bid. Current bid is 15 for Athlete(mean=138.7857982341011, variance=20.80605452375022, position=Position.FORWARD)
# This player is ranked 1
# MONTE CARLO STRAT
# Action: pass, Score: 4.662979867256637
# Action: bid, Score: 4.6225384955752205
# Decision: pass
# 3 is deciding whether to pass or bid. Current bid is 15 for Athlete(mean=138.7857982341011, variance=20.80605452375022, position=Position.FORWARD)
# This player is ranked 1
# MONTE CARLO STRAT
# Action: pass, Score: 5.048030925925925
# Action: bid, Score: 5.254632407407407
# Decision: bid
# 4 is deciding whether to pass or bid. Current bid is 16 for Athlete(mean=138.7857982341011, variance=20.80605452375022, position=Position.FORWARD)
# This player is ranked 1
# MONTE CARLO STRAT
# Action: pass, Score: 4.501584523809523
# Action: bid, Score: 4.564632142857143
# Decision: bid
# 5 is deciding whether to pass or bid. Current bid is 17 for Athlete(mean=138.7857982341011, variance=20.80605452375022, position=Position.FORWARD)
# This player is ranked 1
# VALUE ABOVE REPLACEMENT STRAT
# Decision: pass
# 0 is deciding whether to pass or bid. Current bid is 17 for Athlete(mean=138.7857982341011, variance=20.80605452375022, position=Position.FORWARD)
# This player is ranked 1
# VALUE ABOVE REPLACEMENT STRAT
# Decision: pass
# 3 is deciding whether to pass or bid. Current bid is 17 for Athlete(mean=138.7857982341011, variance=20.80605452375022, position=Position.FORWARD)
# This player is ranked 1
# MONTE CARLO STRAT
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 for i in range(20):
# ----> 2     run_and_display_auction(f'../test_outputs/output{i+3}.txt')
#
# Cell In[2], line 37, in run_and_display_auction(output_file_path, specified)
#      35 strategies = generate_random_strategies(specified)
#      36 export_file = 'auction_results.txt'
# ---> 37 run_auction(export_file, strategies)
#      39 with open(export_file, 'r') as file:
#      40     lines = file.readlines()
#
# File ~/Documents/School/2024-2025/STAT4830/STAT-4830-sparsh-project/src/benchmark_auctions.py:238, in run_auction(export_file, strategies_dict)
#     236 if isinstance(strategy, MONTE_CARLO_STRATEGY):
#     237     print("MONTE CARLO STRAT")
# --> 238     action = strategy.monte_carlo_strategy()
#     239 elif isinstance(strategy, FLIP):
#     240     print("FLIP STRAT")
#
# File ~/Documents/School/2024-2025/STAT4830/STAT-4830-sparsh-project/src/benchmark_auctions.py:40, in MONTE_CARLO_STRATEGY.monte_carlo_strategy(self)
#      38 with Pool(num_processes) as pool:
#      39     for action in range(self.env.action_space.n):
# ---> 40         scores = pool.map(self.monte_carlo_worker, [(self.env, action, simulations_per_process) for _ in range(num_processes)])
#      41         score = np.mean(scores)
#      42         action_text = "pass" if action == 0 else "bid"
#
# File ~/anaconda3/envs/stat4830/lib/python3.9/multiprocessing/pool.py:364, in Pool.map(self, func, iterable, chunksize)
#     359 def map(self, func, iterable, chunksize=None):
#     360     '''
#     361     Apply `func` to each element in `iterable`, collecting the results
#     362     in a list that is returned.
#     363     '''
# --> 364     return self._map_async(func, iterable, mapstar, chunksize).get()
#
# File ~/anaconda3/envs/stat4830/lib/python3.9/multiprocessing/pool.py:765, in ApplyResult.get(self, timeout)
#     764 def get(self, timeout=None):
# --> 765     self.wait(timeout)
#     766     if not self.ready():
#     767         raise TimeoutError
#
# File ~/anaconda3/envs/stat4830/lib/python3.9/multiprocessing/pool.py:762, in ApplyResult.wait(self, timeout)
#     761 def wait(self, timeout=None):
# --> 762     self._event.wait(timeout)
#
# File ~/anaconda3/envs/stat4830/lib/python3.9/threading.py:581, in Event.wait(self, timeout)
#     579 signaled = self._flag
#     580 if not signaled:
# --> 581     signaled = self._cond.wait(timeout)
#     582 return signaled
#
# File ~/anaconda3/envs/stat4830/lib/python3.9/threading.py:312, in Condition.wait(self, timeout)
#     310 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     311     if timeout is None:
# --> 312         waiter.acquire()
#     313         gotit = True
#     314     else:
#
# KeyboardInterrupt:
