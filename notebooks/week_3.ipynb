# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join('..', 'src')))

# %%
import json
from auction_env import AuctionEnv, generate_athletes
from format_roster import format_roster, print_roster
from benchmark_auctions import run_auction
import numpy as np

def generate_random_strategies(specified=None):
    strategies = {}
    if specified is not None:
        for i in range(6):
            strategy_type = specified[i]
            if strategy_type == 'monte_carlo':
                strategies[i] = {'type': 'monte_carlo', 'num_simulations': np.random.randint(50, 150)}
            elif strategy_type == 'flip':
                strategies[i] = {'type': 'flip', 'p': np.random.uniform(0.1, 0.9)}
            elif strategy_type == 'proportional':
                strategies[i] = {'type': 'proportional', 'weight_vector': np.random.dirichlet(np.ones(3), size=1)[0].tolist()}
            elif strategy_type == 'value_above_replacement':
                strategies[i] = {'type': 'value_above_replacement'}
        return strategies
    
    for i in range(6):
        strategy_type = np.random.choice(['monte_carlo', 'flip', 'proportional', 'value_above_replacement'])
        if strategy_type == 'monte_carlo':
            strategies[i] = {'type': 'monte_carlo', 'num_simulations': np.random.randint(50, 150)}
        elif strategy_type == 'flip':
            strategies[i] = {'type': 'flip', 'p': np.random.uniform(0.1, 0.9)}
        elif strategy_type == 'proportional':
            strategies[i] = {'type': 'proportional', 'weight_vector': np.random.dirichlet(np.ones(3), size=1)[0].tolist()}
        elif strategy_type == 'value_above_replacement':
            strategies[i] = {'type': 'value_above_replacement'}
    return strategies

def run_and_display_auction(output_file_path, specified=None):
    strategies = generate_random_strategies(specified)
    export_file = 'auction_results.txt'
    run_auction(export_file, strategies)
    
    with open(export_file, 'r') as file:
        lines = file.readlines()
        history = eval(lines[0], {"np": __import__("numpy"), "Athlete": AuctionEnv.Athlete, "Position": AuctionEnv.Position})
        player_scores = json.loads(lines[1])
    
    teams = format_roster(history, strategies, player_scores)
    with open(output_file_path, 'w') as file:
        print_roster(teams, file)

# %%
specified = ['monte_carlo', 'flip', 'proportional', 'value_above_replacement', 'flip', 'proportional']
run_and_display_auction('../test_outputs/output1.txt', specified)
# Out:
# Auctioning off:
# Player Athlete(mean=196.17524377374855, variance=20.536080560925868, position=Position.FORWARD), Rank: 1)
# Player Athlete(mean=150.416886394619, variance=8.719547663131088, position=Position.GOALIE), Rank: 1)
# Player Athlete(mean=84.78284278578006, variance=10.435611771701033, position=Position.DEFENSEMAN), Rank: 1)
# Player Athlete(mean=149.78698254462384, variance=16.08847184612545, position=Position.FORWARD), Rank: 2)
# Player Athlete(mean=65.44680529137607, variance=6.725332352204721, position=Position.DEFENSEMAN), Rank: 2)
# Player Athlete(mean=93.93643171246345, variance=13.200659508339378, position=Position.GOALIE), Rank: 2)
# Player Athlete(mean=135.1412779345932, variance=13.613991646409263, position=Position.FORWARD), Rank: 3)
# Player Athlete(mean=59.70093125493795, variance=6.044185416050033, position=Position.DEFENSEMAN), Rank: 3)
# Player Athlete(mean=88.72669858916424, variance=12.109884083403912, position=Position.GOALIE), Rank: 3)
# Player Athlete(mean=134.20249085339094, variance=14.207550504082937, position=Position.FORWARD), Rank: 4)
# Player Athlete(mean=80.61782613676542, variance=20.93632512399743, position=Position.GOALIE), Rank: 4)
# Player Athlete(mean=59.263249181076596, variance=5.92953797724207, position=Position.DEFENSEMAN), Rank: 4)
# Player Athlete(mean=123.49663051835664, variance=18.727922271649827, position=Position.FORWARD), Rank: 5)
# Player Athlete(mean=71.52702050680126, variance=41.036201185337134, position=Position.GOALIE), Rank: 5)
# Player Athlete(mean=45.792235251851224, variance=4.601562789271991, position=Position.DEFENSEMAN), Rank: 5)
# Player Athlete(mean=54.0372638301151, variance=36.52950425222598, position=Position.GOALIE), Rank: 6)
# Player Athlete(mean=40.37312146534141, variance=8.43351835452814, position=Position.DEFENSEMAN), Rank: 6)
# Player Athlete(mean=122.6371804276393, variance=19.865091982624037, position=Position.FORWARD), Rank: 6)
# Player Athlete(mean=108.13603076530578, variance=15.987201719110105, position=Position.FORWARD), Rank: 7)
# Player Athlete(mean=48.704159384425665, variance=50.74219146595404, position=Position.GOALIE), Rank: 7)
# Player Athlete(mean=38.77789705147204, variance=7.477905200308171, position=Position.DEFENSEMAN), Rank: 7)
# Player Athlete(mean=96.83918619495729, variance=9.952992149332015, position=Position.FORWARD), Rank: 8)
# Player Athlete(mean=37.15601724670518, variance=11.026825372224707, position=Position.DEFENSEMAN), Rank: 8)
# Player Athlete(mean=45.714640817053265, variance=28.140834826057866, position=Position.GOALIE), Rank: 8)
# Player Athlete(mean=40.96059034944464, variance=70.52004598173679, position=Position.GOALIE), Rank: 9)
# Player Athlete(mean=87.27377658794437, variance=16.446617636802603, position=Position.FORWARD), Rank: 9)
# Player Athlete(mean=33.93933874674949, variance=11.034993060866528, position=Position.DEFENSEMAN), Rank: 9)
# Player Athlete(mean=30.454770601640604, variance=21.679399222793016, position=Position.GOALIE), Rank: 10)
# Player Athlete(mean=33.65599304863831, variance=6.083944541695436, position=Position.DEFENSEMAN), Rank: 10)
# Player Athlete(mean=84.89388904171557, variance=9.666171781362415, position=Position.FORWARD), Rank: 10)
# Player Athlete(mean=28.8492790620039, variance=51.47798927042386, position=Position.GOALIE), Rank: 11)
# Player Athlete(mean=75.4120564952213, variance=9.015533930885457, position=Position.FORWARD), Rank: 11)
# Player Athlete(mean=28.58283906188312, variance=33.09430567280383, position=Position.GOALIE), Rank: 12)
# Player Athlete(mean=73.14833514864875, variance=8.605307584649013, position=Position.FORWARD), Rank: 12)
# Player Athlete(mean=28.10549810946867, variance=9.114259987491392, position=Position.DEFENSEMAN), Rank: 12)
# Player Athlete(mean=21.800479010645937, variance=3.6347525994571597, position=Position.DEFENSEMAN), Rank: 13)
# Player Athlete(mean=72.93167620089498, variance=8.197320121986593, position=Position.FORWARD), Rank: 13)
# Player Athlete(mean=70.05512907753274, variance=8.057864184934578, position=Position.FORWARD), Rank: 14)
# Player Athlete(mean=18.27478205790761, variance=10.458240304079677, position=Position.DEFENSEMAN), Rank: 14)
# Player Athlete(mean=68.8862934142748, variance=6.910330158406515, position=Position.FORWARD), Rank: 15)
# Player Athlete(mean=17.1740542163069, variance=8.478604509154303, position=Position.DEFENSEMAN), Rank: 15)
# Player Athlete(mean=14.11091197911843, variance=3.741447332171285, position=Position.DEFENSEMAN), Rank: 16)
# Player Athlete(mean=56.77305596577918, variance=12.382227130692948, position=Position.FORWARD), Rank: 16)
# Player Athlete(mean=53.56082759033167, variance=14.872841745735656, position=Position.FORWARD), Rank: 17)
# Player Athlete(mean=12.642272558262482, variance=18.973330327493876, position=Position.DEFENSEMAN), Rank: 17)
# Player Athlete(mean=11.664684132027084, variance=26.89722725264187, position=Position.DEFENSEMAN), Rank: 18)
# Player Athlete(mean=51.8503803241442, variance=5.1962189237733165, position=Position.FORWARD), Rank: 18)
# Player Athlete(mean=49.88895428491823, variance=5.308242941610234, position=Position.FORWARD), Rank: 19)
# Player Athlete(mean=9.614852129127518, variance=1.5153063642430182, position=Position.DEFENSEMAN), Rank: 19)
# Player Athlete(mean=48.45911403129727, variance=7.61743587839203, position=Position.FORWARD), Rank: 20)
# Player Athlete(mean=8.34800416834848, variance=0.8351730541391612, position=Position.DEFENSEMAN), Rank: 20)
# Player Athlete(mean=47.38299457356655, variance=5.774625687652351, position=Position.FORWARD), Rank: 21)
# Player Athlete(mean=7.406580829907628, variance=1.1301265509135425, position=Position.DEFENSEMAN), Rank: 21)
# Player Athlete(mean=5.99313385868075, variance=9.020903960470815, position=Position.DEFENSEMAN), Rank: 22)
# Player Athlete(mean=46.52758528675092, variance=11.915190382811542, position=Position.FORWARD), Rank: 22)
# Player Athlete(mean=43.588693254188854, variance=4.525169317428588, position=Position.FORWARD), Rank: 23)
# Player Athlete(mean=4.008441582812833, variance=7.660343690647866, position=Position.DEFENSEMAN), Rank: 23)
# Player Athlete(mean=41.14168627553575, variance=4.308141392758548, position=Position.FORWARD), Rank: 24)
# Player Athlete(mean=3.8632587957382154, variance=0.694328732489139, position=Position.DEFENSEMAN), Rank: 24)
# Player Athlete(mean=41.01535849989724, variance=4.55251141157707, position=Position.FORWARD), Rank: 25)
# Player Athlete(mean=40.95873591488009, variance=30.95191009338942, position=Position.FORWARD), Rank: 26)
# Player Athlete(mean=40.5107724749072, variance=9.157094125043411, position=Position.FORWARD), Rank: 27)
# Player Athlete(mean=36.60560482218643, variance=5.3867881377156674, position=Position.FORWARD), Rank: 28)
# Player Athlete(mean=35.910007433285934, variance=3.7871337064027744, position=Position.FORWARD), Rank: 29)
# Player Athlete(mean=32.95051676317097, variance=5.2995271713956855, position=Position.FORWARD), Rank: 30)
# Player Athlete(mean=32.93242292572763, variance=11.224900382606037, position=Position.FORWARD), Rank: 31)
# Player Athlete(mean=31.627168292458006, variance=8.349563629764274, position=Position.FORWARD), Rank: 32)
# Player Athlete(mean=30.58889166284336, variance=12.12959357582317, position=Position.FORWARD), Rank: 33)
# Player Athlete(mean=29.52919194429697, variance=5.02866448060856, position=Position.FORWARD), Rank: 34)
# Player Athlete(mean=26.283678997827238, variance=2.774836760505577, position=Position.FORWARD), Rank: 35)
# Player Athlete(mean=25.54176863302578, variance=3.4906443465806083, position=Position.FORWARD), Rank: 36)
# Player Athlete(mean=22.930460614157546, variance=15.560250611997434, position=Position.FORWARD), Rank: 37)
# Player Athlete(mean=21.88515819744395, variance=2.775604535991684, position=Position.FORWARD), Rank: 38)
# Player Athlete(mean=21.35588467028258, variance=13.340861419239161, position=Position.FORWARD), Rank: 39)
# Player Athlete(mean=19.60109288023197, variance=3.3148713228402915, position=Position.FORWARD), Rank: 40)
# Player Athlete(mean=16.214818751513295, variance=1.7146787720277796, position=Position.FORWARD), Rank: 41)
# Player Athlete(mean=14.98018637214055, variance=9.870023965708928, position=Position.FORWARD), Rank: 42)
# Player Athlete(mean=14.398204731897152, variance=6.434020922473852, position=Position.FORWARD), Rank: 43)
# Player Athlete(mean=13.464775108878877, variance=3.902417728608701, position=Position.FORWARD), Rank: 44)
# Player Athlete(mean=12.27050249831069, variance=1.747929670352605, position=Position.FORWARD), Rank: 45)
# Player Athlete(mean=6.738923258969067, variance=4.936481939815019, position=Position.FORWARD), Rank: 46)
# Player Athlete(mean=6.017335134017312, variance=11.516109575728077, position=Position.FORWARD), Rank: 47)
# Player Athlete(mean=5.397477729666744, variance=4.069002061411718, position=Position.FORWARD), Rank: 48)
# 1 is deciding whether to pass or bid. Current bid is 0 for Athlete(mean=33.50931213532936, variance=3.784321794817811, position=Position.DEFENSEMAN)
# This player is ranked 11
# FLIP STRAT
# Decision: bid
# 2 is deciding whether to pass or bid. Current bid is 1 for Athlete(mean=33.50931213532936, variance=3.784321794817811, position=Position.DEFENSEMAN)
# This player is ranked 11
# PROPORTIONAL STRAT
# Decision: bid
# 3 is deciding whether to pass or bid. Current bid is 2 for Athlete(mean=33.50931213532936, variance=3.784321794817811, position=Position.DEFENSEMAN)
# This player is ranked 11
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 4 is deciding whether to pass or bid. Current bid is 3 for Athlete(mean=33.50931213532936, variance=3.784321794817811, position=Position.DEFENSEMAN)
# This player is ranked 11
# FLIP STRAT
# Decision: pass
# 5 is deciding whether to pass or bid. Current bid is 3 for Athlete(mean=33.50931213532936, variance=3.784321794817811, position=Position.DEFENSEMAN)
# This player is ranked 11
# PROPORTIONAL STRAT
# Decision: pass
# 0 is deciding whether to pass or bid. Current bid is 3 for Athlete(mean=33.50931213532936, variance=3.784321794817811, position=Position.DEFENSEMAN)
# This player is ranked 11
# MONTE CARLO STRAT
# Action: pass, Score: 3.4697685064935064
# Action: bid, Score: 3.72488474025974
# Decision: bid
# 1 is deciding whether to pass or bid. Current bid is 4 for Athlete(mean=33.50931213532936, variance=3.784321794817811, position=Position.DEFENSEMAN)
# This player is ranked 11
# FLIP STRAT
# Decision: bid
# 2 is deciding whether to pass or bid. Current bid is 5 for Athlete(mean=33.50931213532936, variance=3.784321794817811, position=Position.DEFENSEMAN)
# This player is ranked 11
# PROPORTIONAL STRAT
# Decision: bid
# 3 is deciding whether to pass or bid. Current bid is 6 for Athlete(mean=33.50931213532936, variance=3.784321794817811, position=Position.DEFENSEMAN)
# This player is ranked 11
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 0 is deciding whether to pass or bid. Current bid is 7 for Athlete(mean=33.50931213532936, variance=3.784321794817811, position=Position.DEFENSEMAN)
# This player is ranked 11
# MONTE CARLO STRAT
# Action: pass, Score: 3.3415503246753246
# Action: bid, Score: 3.641856493506493
# Decision: bid
# 1 is deciding whether to pass or bid. Current bid is 8 for Athlete(mean=33.50931213532936, variance=3.784321794817811, position=Position.DEFENSEMAN)
# This player is ranked 11
# FLIP STRAT
# Decision: pass
# 2 is deciding whether to pass or bid. Current bid is 8 for Athlete(mean=33.50931213532936, variance=3.784321794817811, position=Position.DEFENSEMAN)
# This player is ranked 11
# PROPORTIONAL STRAT
# Decision: bid
# 3 is deciding whether to pass or bid. Current bid is 9 for Athlete(mean=33.50931213532936, variance=3.784321794817811, position=Position.DEFENSEMAN)
# This player is ranked 11
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 0 is deciding whether to pass or bid. Current bid is 10 for Athlete(mean=33.50931213532936, variance=3.784321794817811, position=Position.DEFENSEMAN)
# This player is ranked 11
# MONTE CARLO STRAT
# Action: pass, Score: 3.4779701298701298
# Action: bid, Score: 3.563996428571428
# Decision: bid
# 2 is deciding whether to pass or bid. Current bid is 11 for Athlete(mean=33.50931213532936, variance=3.784321794817811, position=Position.DEFENSEMAN)
# This player is ranked 11
# PROPORTIONAL STRAT
# Decision: bid
# 3 is deciding whether to pass or bid. Current bid is 12 for Athlete(mean=33.50931213532936, variance=3.784321794817811, position=Position.DEFENSEMAN)
# This player is ranked 11
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 0 is deciding whether to pass or bid. Current bid is 13 for Athlete(mean=33.50931213532936, variance=3.784321794817811, position=Position.DEFENSEMAN)
# This player is ranked 11
# MONTE CARLO STRAT
# Action: pass, Score: 3.5154321428571427
# Action: bid, Score: 3.634032142857144
# Decision: bid
# 2 is deciding whether to pass or bid. Current bid is 14 for Athlete(mean=33.50931213532936, variance=3.784321794817811, position=Position.DEFENSEMAN)
# This player is ranked 11
# PROPORTIONAL STRAT
# Decision: bid
# 3 is deciding whether to pass or bid. Current bid is 15 for Athlete(mean=33.50931213532936, variance=3.784321794817811, position=Position.DEFENSEMAN)
# This player is ranked 11
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 0 is deciding whether to pass or bid. Current bid is 16 for Athlete(mean=33.50931213532936, variance=3.784321794817811, position=Position.DEFENSEMAN)
# This player is ranked 11
# MONTE CARLO STRAT
# Action: pass, Score: 3.3919977272727277
# Action: bid, Score: 3.6533642857142854
# Decision: bid
# 2 is deciding whether to pass or bid. Current bid is 17 for Athlete(mean=33.50931213532936, variance=3.784321794817811, position=Position.DEFENSEMAN)
# This player is ranked 11
# PROPORTIONAL STRAT
# Decision: bid
# 3 is deciding whether to pass or bid. Current bid is 18 for Athlete(mean=33.50931213532936, variance=3.784321794817811, position=Position.DEFENSEMAN)
# This player is ranked 11
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 0 is deciding whether to pass or bid. Current bid is 19 for Athlete(mean=33.50931213532936, variance=3.784321794817811, position=Position.DEFENSEMAN)
# This player is ranked 11
# MONTE CARLO STRAT
# Action: pass, Score: 3.6243353896103896
# Action: bid, Score: 3.5554006493506494
# Decision: pass
# 2 is deciding whether to pass or bid. Current bid is 19 for Athlete(mean=33.50931213532936, variance=3.784321794817811, position=Position.DEFENSEMAN)
# This player is ranked 11
# PROPORTIONAL STRAT
# Decision: pass
# 3 is deciding whether to pass or bid. Current bid is 0 for Athlete(mean=33.93933874674949, variance=11.034993060866528, position=Position.DEFENSEMAN)
# This player is ranked 9
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 4 is deciding whether to pass or bid. Current bid is 1 for Athlete(mean=33.93933874674949, variance=11.034993060866528, position=Position.DEFENSEMAN)
# This player is ranked 9
# FLIP STRAT
# Decision: bid
# 5 is deciding whether to pass or bid. Current bid is 2 for Athlete(mean=33.93933874674949, variance=11.034993060866528, position=Position.DEFENSEMAN)
# This player is ranked 9
# PROPORTIONAL STRAT
# Decision: pass
# 0 is deciding whether to pass or bid. Current bid is 2 for Athlete(mean=33.93933874674949, variance=11.034993060866528, position=Position.DEFENSEMAN)
# This player is ranked 9
# MONTE CARLO STRAT
# Action: pass, Score: 3.2792116883116886
# Action: bid, Score: 3.530441233766234
# Decision: bid
# 1 is deciding whether to pass or bid. Current bid is 3 for Athlete(mean=33.93933874674949, variance=11.034993060866528, position=Position.DEFENSEMAN)
# This player is ranked 9
# FLIP STRAT
# Decision: bid
# 2 is deciding whether to pass or bid. Current bid is 4 for Athlete(mean=33.93933874674949, variance=11.034993060866528, position=Position.DEFENSEMAN)
# This player is ranked 9
# PROPORTIONAL STRAT
# Decision: bid
# 3 is deciding whether to pass or bid. Current bid is 5 for Athlete(mean=33.93933874674949, variance=11.034993060866528, position=Position.DEFENSEMAN)
# This player is ranked 9
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 4 is deciding whether to pass or bid. Current bid is 6 for Athlete(mean=33.93933874674949, variance=11.034993060866528, position=Position.DEFENSEMAN)
# This player is ranked 9
# FLIP STRAT
# Decision: pass
# 0 is deciding whether to pass or bid. Current bid is 6 for Athlete(mean=33.93933874674949, variance=11.034993060866528, position=Position.DEFENSEMAN)
# This player is ranked 9
# MONTE CARLO STRAT
# Action: pass, Score: 3.473190584415585
# Action: bid, Score: 3.514083441558441
# Decision: bid
# 1 is deciding whether to pass or bid. Current bid is 7 for Athlete(mean=33.93933874674949, variance=11.034993060866528, position=Position.DEFENSEMAN)
# This player is ranked 9
# FLIP STRAT
# Decision: pass
# 2 is deciding whether to pass or bid. Current bid is 7 for Athlete(mean=33.93933874674949, variance=11.034993060866528, position=Position.DEFENSEMAN)
# This player is ranked 9
# PROPORTIONAL STRAT
# Decision: bid
# 3 is deciding whether to pass or bid. Current bid is 8 for Athlete(mean=33.93933874674949, variance=11.034993060866528, position=Position.DEFENSEMAN)
# This player is ranked 9
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 0 is deciding whether to pass or bid. Current bid is 9 for Athlete(mean=33.93933874674949, variance=11.034993060866528, position=Position.DEFENSEMAN)
# This player is ranked 9
# MONTE CARLO STRAT
# Action: pass, Score: 3.5666944805194807
# Action: bid, Score: 3.463752597402597
# Decision: pass
# 2 is deciding whether to pass or bid. Current bid is 9 for Athlete(mean=33.93933874674949, variance=11.034993060866528, position=Position.DEFENSEMAN)
# This player is ranked 9
# PROPORTIONAL STRAT
# Decision: bid
# 3 is deciding whether to pass or bid. Current bid is 10 for Athlete(mean=33.93933874674949, variance=11.034993060866528, position=Position.DEFENSEMAN)
# This player is ranked 9
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 2 is deciding whether to pass or bid. Current bid is 11 for Athlete(mean=33.93933874674949, variance=11.034993060866528, position=Position.DEFENSEMAN)
# This player is ranked 9
# PROPORTIONAL STRAT
# Decision: bid
# 3 is deciding whether to pass or bid. Current bid is 12 for Athlete(mean=33.93933874674949, variance=11.034993060866528, position=Position.DEFENSEMAN)
# This player is ranked 9
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 2 is deciding whether to pass or bid. Current bid is 13 for Athlete(mean=33.93933874674949, variance=11.034993060866528, position=Position.DEFENSEMAN)
# This player is ranked 9
# PROPORTIONAL STRAT
# Decision: bid
# 3 is deciding whether to pass or bid. Current bid is 14 for Athlete(mean=33.93933874674949, variance=11.034993060866528, position=Position.DEFENSEMAN)
# This player is ranked 9
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 2 is deciding whether to pass or bid. Current bid is 15 for Athlete(mean=33.93933874674949, variance=11.034993060866528, position=Position.DEFENSEMAN)
# This player is ranked 9
# PROPORTIONAL STRAT
# Decision: bid
# 3 is deciding whether to pass or bid. Current bid is 16 for Athlete(mean=33.93933874674949, variance=11.034993060866528, position=Position.DEFENSEMAN)
# This player is ranked 9
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 2 is deciding whether to pass or bid. Current bid is 17 for Athlete(mean=33.93933874674949, variance=11.034993060866528, position=Position.DEFENSEMAN)
# This player is ranked 9
# PROPORTIONAL STRAT
# Decision: bid
# 3 is deciding whether to pass or bid. Current bid is 18 for Athlete(mean=33.93933874674949, variance=11.034993060866528, position=Position.DEFENSEMAN)
# This player is ranked 9
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 2 is deciding whether to pass or bid. Current bid is 19 for Athlete(mean=33.93933874674949, variance=11.034993060866528, position=Position.DEFENSEMAN)
# This player is ranked 9
# PROPORTIONAL STRAT
# Decision: bid
# 3 is deciding whether to pass or bid. Current bid is 20 for Athlete(mean=33.93933874674949, variance=11.034993060866528, position=Position.DEFENSEMAN)
# This player is ranked 9
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 2 is deciding whether to pass or bid. Current bid is 21 for Athlete(mean=33.93933874674949, variance=11.034993060866528, position=Position.DEFENSEMAN)
# This player is ranked 9
# PROPORTIONAL STRAT
# Decision: pass
# 3 is deciding whether to pass or bid. Current bid is 0 for Athlete(mean=8.34800416834848, variance=0.8351730541391612, position=Position.DEFENSEMAN)
# This player is ranked 20
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 4 is deciding whether to pass or bid. Current bid is 1 for Athlete(mean=8.34800416834848, variance=0.8351730541391612, position=Position.DEFENSEMAN)
# This player is ranked 20
# FLIP STRAT
# Decision: pass
# 5 is deciding whether to pass or bid. Current bid is 1 for Athlete(mean=8.34800416834848, variance=0.8351730541391612, position=Position.DEFENSEMAN)
# This player is ranked 20
# PROPORTIONAL STRAT
# Decision: pass
# 0 is deciding whether to pass or bid. Current bid is 1 for Athlete(mean=8.34800416834848, variance=0.8351730541391612, position=Position.DEFENSEMAN)
# This player is ranked 20
# MONTE CARLO STRAT
# Action: pass, Score: 3.6113613636363633
# Action: bid, Score: 3.4472665584415583
# Decision: pass
# 1 is deciding whether to pass or bid. Current bid is 1 for Athlete(mean=8.34800416834848, variance=0.8351730541391612, position=Position.DEFENSEMAN)
# This player is ranked 20
# FLIP STRAT
# Decision: pass
# 2 is deciding whether to pass or bid. Current bid is 1 for Athlete(mean=8.34800416834848, variance=0.8351730541391612, position=Position.DEFENSEMAN)
# This player is ranked 20
# PROPORTIONAL STRAT
# Decision: bid
# 3 is deciding whether to pass or bid. Current bid is 2 for Athlete(mean=8.34800416834848, variance=0.8351730541391612, position=Position.DEFENSEMAN)
# This player is ranked 20
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 2 is deciding whether to pass or bid. Current bid is 3 for Athlete(mean=8.34800416834848, variance=0.8351730541391612, position=Position.DEFENSEMAN)
# This player is ranked 20
# PROPORTIONAL STRAT
# Decision: bid
# 3 is deciding whether to pass or bid. Current bid is 4 for Athlete(mean=8.34800416834848, variance=0.8351730541391612, position=Position.DEFENSEMAN)
# This player is ranked 20
# VALUE ABOVE REPLACEMENT STRAT
# Decision: pass
# 4 is deciding whether to pass or bid. Current bid is 0 for Athlete(mean=18.27478205790761, variance=10.458240304079677, position=Position.DEFENSEMAN)
# This player is ranked 14
# FLIP STRAT
# Decision: pass
# 5 is deciding whether to pass or bid. Current bid is 0 for Athlete(mean=18.27478205790761, variance=10.458240304079677, position=Position.DEFENSEMAN)
# This player is ranked 14
# PROPORTIONAL STRAT
# Decision: bid
# 0 is deciding whether to pass or bid. Current bid is 1 for Athlete(mean=18.27478205790761, variance=10.458240304079677, position=Position.DEFENSEMAN)
# This player is ranked 14
# MONTE CARLO STRAT
# Action: pass, Score: 3.45466525974026
# Action: bid, Score: 3.5982564935064936
# Decision: bid
# 1 is deciding whether to pass or bid. Current bid is 2 for Athlete(mean=18.27478205790761, variance=10.458240304079677, position=Position.DEFENSEMAN)
# This player is ranked 14
# FLIP STRAT
# Decision: pass
# 2 is deciding whether to pass or bid. Current bid is 2 for Athlete(mean=18.27478205790761, variance=10.458240304079677, position=Position.DEFENSEMAN)
# This player is ranked 14
# PROPORTIONAL STRAT
# Decision: bid
# 3 is deciding whether to pass or bid. Current bid is 3 for Athlete(mean=18.27478205790761, variance=10.458240304079677, position=Position.DEFENSEMAN)
# This player is ranked 14
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 5 is deciding whether to pass or bid. Current bid is 4 for Athlete(mean=18.27478205790761, variance=10.458240304079677, position=Position.DEFENSEMAN)
# This player is ranked 14
# PROPORTIONAL STRAT
# Decision: pass
# 0 is deciding whether to pass or bid. Current bid is 4 for Athlete(mean=18.27478205790761, variance=10.458240304079677, position=Position.DEFENSEMAN)
# This player is ranked 14
# MONTE CARLO STRAT
# Action: pass, Score: 3.4687954545454547
# Action: bid, Score: 3.509988961038962
# Decision: bid
# 2 is deciding whether to pass or bid. Current bid is 5 for Athlete(mean=18.27478205790761, variance=10.458240304079677, position=Position.DEFENSEMAN)
# This player is ranked 14
# PROPORTIONAL STRAT
# Decision: bid
# 3 is deciding whether to pass or bid. Current bid is 6 for Athlete(mean=18.27478205790761, variance=10.458240304079677, position=Position.DEFENSEMAN)
# This player is ranked 14
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 0 is deciding whether to pass or bid. Current bid is 7 for Athlete(mean=18.27478205790761, variance=10.458240304079677, position=Position.DEFENSEMAN)
# This player is ranked 14
# MONTE CARLO STRAT
# Action: pass, Score: 3.3596727272727276
# Action: bid, Score: 3.5591922077922074
# Decision: bid
# 2 is deciding whether to pass or bid. Current bid is 8 for Athlete(mean=18.27478205790761, variance=10.458240304079677, position=Position.DEFENSEMAN)
# This player is ranked 14
# PROPORTIONAL STRAT
# Decision: bid
# 3 is deciding whether to pass or bid. Current bid is 9 for Athlete(mean=18.27478205790761, variance=10.458240304079677, position=Position.DEFENSEMAN)
# This player is ranked 14
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 0 is deciding whether to pass or bid. Current bid is 10 for Athlete(mean=18.27478205790761, variance=10.458240304079677, position=Position.DEFENSEMAN)
# This player is ranked 14
# MONTE CARLO STRAT
# Action: pass, Score: 3.649367857142857
# Action: bid, Score: 3.6162035714285716
# Decision: pass
# 2 is deciding whether to pass or bid. Current bid is 10 for Athlete(mean=18.27478205790761, variance=10.458240304079677, position=Position.DEFENSEMAN)
# This player is ranked 14
# PROPORTIONAL STRAT
# Decision: bid
# 3 is deciding whether to pass or bid. Current bid is 11 for Athlete(mean=18.27478205790761, variance=10.458240304079677, position=Position.DEFENSEMAN)
# This player is ranked 14
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 2 is deciding whether to pass or bid. Current bid is 12 for Athlete(mean=18.27478205790761, variance=10.458240304079677, position=Position.DEFENSEMAN)
# This player is ranked 14
# PROPORTIONAL STRAT
# Decision: pass
# 3 is deciding whether to pass or bid. Current bid is 0 for Athlete(mean=122.6371804276393, variance=19.865091982624037, position=Position.FORWARD)
# This player is ranked 6
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 4 is deciding whether to pass or bid. Current bid is 1 for Athlete(mean=122.6371804276393, variance=19.865091982624037, position=Position.FORWARD)
# This player is ranked 6
# FLIP STRAT
# Decision: pass
# 5 is deciding whether to pass or bid. Current bid is 1 for Athlete(mean=122.6371804276393, variance=19.865091982624037, position=Position.FORWARD)
# This player is ranked 6
# PROPORTIONAL STRAT
# Decision: bid
# 0 is deciding whether to pass or bid. Current bid is 2 for Athlete(mean=122.6371804276393, variance=19.865091982624037, position=Position.FORWARD)
# This player is ranked 6
# MONTE CARLO STRAT
# Action: pass, Score: 3.3511363636363636
# Action: bid, Score: 3.5430110389610388
# Decision: bid
# 1 is deciding whether to pass or bid. Current bid is 3 for Athlete(mean=122.6371804276393, variance=19.865091982624037, position=Position.FORWARD)
# This player is ranked 6
# FLIP STRAT
# Decision: pass
# 2 is deciding whether to pass or bid. Current bid is 3 for Athlete(mean=122.6371804276393, variance=19.865091982624037, position=Position.FORWARD)
# This player is ranked 6
# PROPORTIONAL STRAT
# Decision: bid
# 3 is deciding whether to pass or bid. Current bid is 4 for Athlete(mean=122.6371804276393, variance=19.865091982624037, position=Position.FORWARD)
# This player is ranked 6
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 5 is deciding whether to pass or bid. Current bid is 5 for Athlete(mean=122.6371804276393, variance=19.865091982624037, position=Position.FORWARD)
# This player is ranked 6
# PROPORTIONAL STRAT
# Decision: bid
# 0 is deciding whether to pass or bid. Current bid is 6 for Athlete(mean=122.6371804276393, variance=19.865091982624037, position=Position.FORWARD)
# This player is ranked 6
# MONTE CARLO STRAT
# Action: pass, Score: 3.4577
# Action: bid, Score: 3.651791233766234
# Decision: bid
# 2 is deciding whether to pass or bid. Current bid is 7 for Athlete(mean=122.6371804276393, variance=19.865091982624037, position=Position.FORWARD)
# This player is ranked 6
# PROPORTIONAL STRAT
# Decision: pass
# 3 is deciding whether to pass or bid. Current bid is 7 for Athlete(mean=122.6371804276393, variance=19.865091982624037, position=Position.FORWARD)
# This player is ranked 6
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 5 is deciding whether to pass or bid. Current bid is 8 for Athlete(mean=122.6371804276393, variance=19.865091982624037, position=Position.FORWARD)
# This player is ranked 6
# PROPORTIONAL STRAT
# Decision: bid
# 0 is deciding whether to pass or bid. Current bid is 9 for Athlete(mean=122.6371804276393, variance=19.865091982624037, position=Position.FORWARD)
# This player is ranked 6
# MONTE CARLO STRAT
# Action: pass, Score: 3.448306168831169
# Action: bid, Score: 3.8094785714285706
# Decision: bid
# 3 is deciding whether to pass or bid. Current bid is 10 for Athlete(mean=122.6371804276393, variance=19.865091982624037, position=Position.FORWARD)
# This player is ranked 6
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 5 is deciding whether to pass or bid. Current bid is 11 for Athlete(mean=122.6371804276393, variance=19.865091982624037, position=Position.FORWARD)
# This player is ranked 6
# PROPORTIONAL STRAT
# Decision: pass
# 0 is deciding whether to pass or bid. Current bid is 11 for Athlete(mean=122.6371804276393, variance=19.865091982624037, position=Position.FORWARD)
# This player is ranked 6
# MONTE CARLO STRAT
# Action: pass, Score: 3.5426311688311687
# Action: bid, Score: 3.9661301948051935
# Decision: bid
# 3 is deciding whether to pass or bid. Current bid is 12 for Athlete(mean=122.6371804276393, variance=19.865091982624037, position=Position.FORWARD)
# This player is ranked 6
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 0 is deciding whether to pass or bid. Current bid is 13 for Athlete(mean=122.6371804276393, variance=19.865091982624037, position=Position.FORWARD)
# This player is ranked 6
# MONTE CARLO STRAT
# Action: pass, Score: 3.512371753246753
# Action: bid, Score: 3.854476948051947
# Decision: bid
# 3 is deciding whether to pass or bid. Current bid is 14 for Athlete(mean=122.6371804276393, variance=19.865091982624037, position=Position.FORWARD)
# This player is ranked 6
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 0 is deciding whether to pass or bid. Current bid is 15 for Athlete(mean=122.6371804276393, variance=19.865091982624037, position=Position.FORWARD)
# This player is ranked 6
# MONTE CARLO STRAT
# Action: pass, Score: 3.54394577922078
# Action: bid, Score: 3.8694172077922078
# Decision: bid
# 3 is deciding whether to pass or bid. Current bid is 16 for Athlete(mean=122.6371804276393, variance=19.865091982624037, position=Position.FORWARD)
# This player is ranked 6
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 0 is deciding whether to pass or bid. Current bid is 17 for Athlete(mean=122.6371804276393, variance=19.865091982624037, position=Position.FORWARD)
# This player is ranked 6
# MONTE CARLO STRAT
# Action: pass, Score: 3.5192448051948055
# Action: bid, Score: 4.0425620129870135
# Decision: bid
# 3 is deciding whether to pass or bid. Current bid is 18 for Athlete(mean=122.6371804276393, variance=19.865091982624037, position=Position.FORWARD)
# This player is ranked 6
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 0 is deciding whether to pass or bid. Current bid is 19 for Athlete(mean=122.6371804276393, variance=19.865091982624037, position=Position.FORWARD)
# This player is ranked 6
# MONTE CARLO STRAT
# Action: pass, Score: 3.6398876623376624
# Action: bid, Score: 4.0719120129870126
# Decision: bid
# 3 is deciding whether to pass or bid. Current bid is 20 for Athlete(mean=122.6371804276393, variance=19.865091982624037, position=Position.FORWARD)
# This player is ranked 6
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 0 is deciding whether to pass or bid. Current bid is 21 for Athlete(mean=122.6371804276393, variance=19.865091982624037, position=Position.FORWARD)
# This player is ranked 6
# MONTE CARLO STRAT
# Action: pass, Score: 3.568872077922078
# Action: bid, Score: 4.057575
# Decision: bid
# 3 is deciding whether to pass or bid. Current bid is 22 for Athlete(mean=122.6371804276393, variance=19.865091982624037, position=Position.FORWARD)
# This player is ranked 6
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 0 is deciding whether to pass or bid. Current bid is 23 for Athlete(mean=122.6371804276393, variance=19.865091982624037, position=Position.FORWARD)
# This player is ranked 6
# MONTE CARLO STRAT
# Action: pass, Score: 3.775957792207792
# Action: bid, Score: 3.9121918831168836
# Decision: bid
# 3 is deciding whether to pass or bid. Current bid is 24 for Athlete(mean=122.6371804276393, variance=19.865091982624037, position=Position.FORWARD)
# This player is ranked 6
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 0 is deciding whether to pass or bid. Current bid is 25 for Athlete(mean=122.6371804276393, variance=19.865091982624037, position=Position.FORWARD)
# This player is ranked 6
# MONTE CARLO STRAT
# Action: pass, Score: 3.7435548701298695
# Action: bid, Score: 3.9494928571428582
# Decision: bid
# 3 is deciding whether to pass or bid. Current bid is 26 for Athlete(mean=122.6371804276393, variance=19.865091982624037, position=Position.FORWARD)
# This player is ranked 6
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 0 is deciding whether to pass or bid. Current bid is 27 for Athlete(mean=122.6371804276393, variance=19.865091982624037, position=Position.FORWARD)
# This player is ranked 6
# MONTE CARLO STRAT
# Action: pass, Score: 3.7803590909090907
# Action: bid, Score: 3.98575974025974
# Decision: bid
# 3 is deciding whether to pass or bid. Current bid is 28 for Athlete(mean=122.6371804276393, variance=19.865091982624037, position=Position.FORWARD)
# This player is ranked 6
# VALUE ABOVE REPLACEMENT STRAT
# Decision: pass
# 4 is deciding whether to pass or bid. Current bid is 0 for Athlete(mean=45.714640817053265, variance=28.140834826057866, position=Position.GOALIE)
# This player is ranked 8
# FLIP STRAT
# Decision: pass
# 5 is deciding whether to pass or bid. Current bid is 0 for Athlete(mean=45.714640817053265, variance=28.140834826057866, position=Position.GOALIE)
# This player is ranked 8
# PROPORTIONAL STRAT
# Decision: bid
# 0 is deciding whether to pass or bid. Current bid is 1 for Athlete(mean=45.714640817053265, variance=28.140834826057866, position=Position.GOALIE)
# This player is ranked 8
# MONTE CARLO STRAT
# Action: pass, Score: 4.097150974025974
# Action: bid, Score: 4.23897987012987
# Decision: bid
# 1 is deciding whether to pass or bid. Current bid is 2 for Athlete(mean=45.714640817053265, variance=28.140834826057866, position=Position.GOALIE)
# This player is ranked 8
# FLIP STRAT
# Decision: pass
# 2 is deciding whether to pass or bid. Current bid is 2 for Athlete(mean=45.714640817053265, variance=28.140834826057866, position=Position.GOALIE)
# This player is ranked 8
# PROPORTIONAL STRAT
# Decision: pass
# 3 is deciding whether to pass or bid. Current bid is 2 for Athlete(mean=45.714640817053265, variance=28.140834826057866, position=Position.GOALIE)
# This player is ranked 8
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 5 is deciding whether to pass or bid. Current bid is 3 for Athlete(mean=45.714640817053265, variance=28.140834826057866, position=Position.GOALIE)
# This player is ranked 8
# PROPORTIONAL STRAT
# Decision: bid
# 0 is deciding whether to pass or bid. Current bid is 4 for Athlete(mean=45.714640817053265, variance=28.140834826057866, position=Position.GOALIE)
# This player is ranked 8
# MONTE CARLO STRAT
# Action: pass, Score: 4.31610357142857
# Action: bid, Score: 4.245358441558441
# Decision: pass
# 3 is deciding whether to pass or bid. Current bid is 4 for Athlete(mean=45.714640817053265, variance=28.140834826057866, position=Position.GOALIE)
# This player is ranked 8
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 5 is deciding whether to pass or bid. Current bid is 5 for Athlete(mean=45.714640817053265, variance=28.140834826057866, position=Position.GOALIE)
# This player is ranked 8
# PROPORTIONAL STRAT
# Decision: bid
# 3 is deciding whether to pass or bid. Current bid is 6 for Athlete(mean=45.714640817053265, variance=28.140834826057866, position=Position.GOALIE)
# This player is ranked 8
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 5 is deciding whether to pass or bid. Current bid is 7 for Athlete(mean=45.714640817053265, variance=28.140834826057866, position=Position.GOALIE)
# This player is ranked 8
# PROPORTIONAL STRAT
# Decision: bid
# 3 is deciding whether to pass or bid. Current bid is 8 for Athlete(mean=45.714640817053265, variance=28.140834826057866, position=Position.GOALIE)
# This player is ranked 8
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 5 is deciding whether to pass or bid. Current bid is 9 for Athlete(mean=45.714640817053265, variance=28.140834826057866, position=Position.GOALIE)
# This player is ranked 8
# PROPORTIONAL STRAT
# Decision: bid
# 3 is deciding whether to pass or bid. Current bid is 10 for Athlete(mean=45.714640817053265, variance=28.140834826057866, position=Position.GOALIE)
# This player is ranked 8
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 5 is deciding whether to pass or bid. Current bid is 11 for Athlete(mean=45.714640817053265, variance=28.140834826057866, position=Position.GOALIE)
# This player is ranked 8
# PROPORTIONAL STRAT
# Decision: bid
# 3 is deciding whether to pass or bid. Current bid is 12 for Athlete(mean=45.714640817053265, variance=28.140834826057866, position=Position.GOALIE)
# This player is ranked 8
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 5 is deciding whether to pass or bid. Current bid is 13 for Athlete(mean=45.714640817053265, variance=28.140834826057866, position=Position.GOALIE)
# This player is ranked 8
# PROPORTIONAL STRAT
# Decision: bid
# 3 is deciding whether to pass or bid. Current bid is 14 for Athlete(mean=45.714640817053265, variance=28.140834826057866, position=Position.GOALIE)
# This player is ranked 8
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 5 is deciding whether to pass or bid. Current bid is 15 for Athlete(mean=45.714640817053265, variance=28.140834826057866, position=Position.GOALIE)
# This player is ranked 8
# PROPORTIONAL STRAT
# Decision: bid
# 3 is deciding whether to pass or bid. Current bid is 16 for Athlete(mean=45.714640817053265, variance=28.140834826057866, position=Position.GOALIE)
# This player is ranked 8
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 5 is deciding whether to pass or bid. Current bid is 17 for Athlete(mean=45.714640817053265, variance=28.140834826057866, position=Position.GOALIE)
# This player is ranked 8
# PROPORTIONAL STRAT
# Decision: pass
# 0 is deciding whether to pass or bid. Current bid is 0 for Athlete(mean=88.72669858916424, variance=12.109884083403912, position=Position.GOALIE)
# This player is ranked 3
# MONTE CARLO STRAT
# Action: pass, Score: 4.4303928571428575
# Action: bid, Score: 4.273057467532467
# Decision: pass
# 1 is deciding whether to pass or bid. Current bid is 0 for Athlete(mean=88.72669858916424, variance=12.109884083403912, position=Position.GOALIE)
# This player is ranked 3
# FLIP STRAT
# Decision: bid
# 2 is deciding whether to pass or bid. Current bid is 1 for Athlete(mean=88.72669858916424, variance=12.109884083403912, position=Position.GOALIE)
# This player is ranked 3
# PROPORTIONAL STRAT
# Decision: pass
# 3 is deciding whether to pass or bid. Current bid is 1 for Athlete(mean=88.72669858916424, variance=12.109884083403912, position=Position.GOALIE)
# This player is ranked 3
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 4 is deciding whether to pass or bid. Current bid is 2 for Athlete(mean=88.72669858916424, variance=12.109884083403912, position=Position.GOALIE)
# This player is ranked 3
# FLIP STRAT
# Decision: pass
# 5 is deciding whether to pass or bid. Current bid is 2 for Athlete(mean=88.72669858916424, variance=12.109884083403912, position=Position.GOALIE)
# This player is ranked 3
# PROPORTIONAL STRAT
# Decision: bid
# 1 is deciding whether to pass or bid. Current bid is 3 for Athlete(mean=88.72669858916424, variance=12.109884083403912, position=Position.GOALIE)
# This player is ranked 3
# FLIP STRAT
# Decision: pass
# 3 is deciding whether to pass or bid. Current bid is 3 for Athlete(mean=88.72669858916424, variance=12.109884083403912, position=Position.GOALIE)
# This player is ranked 3
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 5 is deciding whether to pass or bid. Current bid is 4 for Athlete(mean=88.72669858916424, variance=12.109884083403912, position=Position.GOALIE)
# This player is ranked 3
# PROPORTIONAL STRAT
# Decision: bid
# 3 is deciding whether to pass or bid. Current bid is 5 for Athlete(mean=88.72669858916424, variance=12.109884083403912, position=Position.GOALIE)
# This player is ranked 3
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 5 is deciding whether to pass or bid. Current bid is 6 for Athlete(mean=88.72669858916424, variance=12.109884083403912, position=Position.GOALIE)
# This player is ranked 3
# PROPORTIONAL STRAT
# Decision: bid
# 3 is deciding whether to pass or bid. Current bid is 7 for Athlete(mean=88.72669858916424, variance=12.109884083403912, position=Position.GOALIE)
# This player is ranked 3
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 5 is deciding whether to pass or bid. Current bid is 8 for Athlete(mean=88.72669858916424, variance=12.109884083403912, position=Position.GOALIE)
# This player is ranked 3
# PROPORTIONAL STRAT
# Decision: bid
# 3 is deciding whether to pass or bid. Current bid is 9 for Athlete(mean=88.72669858916424, variance=12.109884083403912, position=Position.GOALIE)
# This player is ranked 3
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 5 is deciding whether to pass or bid. Current bid is 10 for Athlete(mean=88.72669858916424, variance=12.109884083403912, position=Position.GOALIE)
# This player is ranked 3
# PROPORTIONAL STRAT
# Decision: bid
# 3 is deciding whether to pass or bid. Current bid is 11 for Athlete(mean=88.72669858916424, variance=12.109884083403912, position=Position.GOALIE)
# This player is ranked 3
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 5 is deciding whether to pass or bid. Current bid is 12 for Athlete(mean=88.72669858916424, variance=12.109884083403912, position=Position.GOALIE)
# This player is ranked 3
# PROPORTIONAL STRAT
# Decision: bid
# 3 is deciding whether to pass or bid. Current bid is 13 for Athlete(mean=88.72669858916424, variance=12.109884083403912, position=Position.GOALIE)
# This player is ranked 3
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 5 is deciding whether to pass or bid. Current bid is 14 for Athlete(mean=88.72669858916424, variance=12.109884083403912, position=Position.GOALIE)
# This player is ranked 3
# PROPORTIONAL STRAT
# Decision: bid
# 3 is deciding whether to pass or bid. Current bid is 15 for Athlete(mean=88.72669858916424, variance=12.109884083403912, position=Position.GOALIE)
# This player is ranked 3
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 5 is deciding whether to pass or bid. Current bid is 16 for Athlete(mean=88.72669858916424, variance=12.109884083403912, position=Position.GOALIE)
# This player is ranked 3
# PROPORTIONAL STRAT
# Decision: bid
# 3 is deciding whether to pass or bid. Current bid is 17 for Athlete(mean=88.72669858916424, variance=12.109884083403912, position=Position.GOALIE)
# This player is ranked 3
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 5 is deciding whether to pass or bid. Current bid is 18 for Athlete(mean=88.72669858916424, variance=12.109884083403912, position=Position.GOALIE)
# This player is ranked 3
# PROPORTIONAL STRAT
# Decision: bid
# 3 is deciding whether to pass or bid. Current bid is 19 for Athlete(mean=88.72669858916424, variance=12.109884083403912, position=Position.GOALIE)
# This player is ranked 3
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 5 is deciding whether to pass or bid. Current bid is 20 for Athlete(mean=88.72669858916424, variance=12.109884083403912, position=Position.GOALIE)
# This player is ranked 3
# PROPORTIONAL STRAT
# Decision: bid
# 3 is deciding whether to pass or bid. Current bid is 21 for Athlete(mean=88.72669858916424, variance=12.109884083403912, position=Position.GOALIE)
# This player is ranked 3
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 5 is deciding whether to pass or bid. Current bid is 22 for Athlete(mean=88.72669858916424, variance=12.109884083403912, position=Position.GOALIE)
# This player is ranked 3
# PROPORTIONAL STRAT
# Decision: bid
# 3 is deciding whether to pass or bid. Current bid is 23 for Athlete(mean=88.72669858916424, variance=12.109884083403912, position=Position.GOALIE)
# This player is ranked 3
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 5 is deciding whether to pass or bid. Current bid is 24 for Athlete(mean=88.72669858916424, variance=12.109884083403912, position=Position.GOALIE)
# This player is ranked 3
# PROPORTIONAL STRAT
# Decision: bid
# 3 is deciding whether to pass or bid. Current bid is 25 for Athlete(mean=88.72669858916424, variance=12.109884083403912, position=Position.GOALIE)
# This player is ranked 3
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 5 is deciding whether to pass or bid. Current bid is 26 for Athlete(mean=88.72669858916424, variance=12.109884083403912, position=Position.GOALIE)
# This player is ranked 3
# PROPORTIONAL STRAT
# Decision: bid
# 3 is deciding whether to pass or bid. Current bid is 27 for Athlete(mean=88.72669858916424, variance=12.109884083403912, position=Position.GOALIE)
# This player is ranked 3
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 5 is deciding whether to pass or bid. Current bid is 28 for Athlete(mean=88.72669858916424, variance=12.109884083403912, position=Position.GOALIE)
# This player is ranked 3
# PROPORTIONAL STRAT
# Decision: bid
# 3 is deciding whether to pass or bid. Current bid is 29 for Athlete(mean=88.72669858916424, variance=12.109884083403912, position=Position.GOALIE)
# This player is ranked 3
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 5 is deciding whether to pass or bid. Current bid is 30 for Athlete(mean=88.72669858916424, variance=12.109884083403912, position=Position.GOALIE)
# This player is ranked 3
# PROPORTIONAL STRAT
# Decision: bid
# 3 is deciding whether to pass or bid. Current bid is 31 for Athlete(mean=88.72669858916424, variance=12.109884083403912, position=Position.GOALIE)
# This player is ranked 3
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 5 is deciding whether to pass or bid. Current bid is 32 for Athlete(mean=88.72669858916424, variance=12.109884083403912, position=Position.GOALIE)
# This player is ranked 3
# PROPORTIONAL STRAT
# Decision: pass
# 0 is deciding whether to pass or bid. Current bid is 0 for Athlete(mean=93.93643171246345, variance=13.200659508339378, position=Position.GOALIE)
# This player is ranked 2
# MONTE CARLO STRAT
# Action: pass, Score: 4.4462487012987015
# Action: bid, Score: 4.605314610389611
# Decision: bid
# 1 is deciding whether to pass or bid. Current bid is 1 for Athlete(mean=93.93643171246345, variance=13.200659508339378, position=Position.GOALIE)
# This player is ranked 2
# FLIP STRAT
# Decision: pass
# 2 is deciding whether to pass or bid. Current bid is 1 for Athlete(mean=93.93643171246345, variance=13.200659508339378, position=Position.GOALIE)
# This player is ranked 2
# PROPORTIONAL STRAT
# Decision: pass
# 3 is deciding whether to pass or bid. Current bid is 1 for Athlete(mean=93.93643171246345, variance=13.200659508339378, position=Position.GOALIE)
# This player is ranked 2
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 4 is deciding whether to pass or bid. Current bid is 1 for Athlete(mean=93.93643171246345, variance=13.200659508339378, position=Position.GOALIE)
# This player is ranked 2
# FLIP STRAT
# Decision: bid
# 5 is deciding whether to pass or bid. Current bid is 2 for Athlete(mean=93.93643171246345, variance=13.200659508339378, position=Position.GOALIE)
# This player is ranked 2
# PROPORTIONAL STRAT
# Decision: bid
# 0 is deciding whether to pass or bid. Current bid is 3 for Athlete(mean=93.93643171246345, variance=13.200659508339378, position=Position.GOALIE)
# This player is ranked 2
# MONTE CARLO STRAT
# Action: pass, Score: 4.44924935064935
# Action: bid, Score: 4.508141558441558
# Decision: bid
# 4 is deciding whether to pass or bid. Current bid is 4 for Athlete(mean=93.93643171246345, variance=13.200659508339378, position=Position.GOALIE)
# This player is ranked 2
# FLIP STRAT
# Decision: pass
# ...
# This player is ranked 28
# FLIP STRAT
# Decision: bid
# 5 is deciding whether to pass or bid. Current bid is 2 for Athlete(mean=36.60560482218643, variance=5.3867881377156674, position=Position.FORWARD)
# This player is ranked 28
# PROPORTIONAL STRAT
# Decision: bid
# 0 is deciding whether to pass or bid. Current bid is 2 for Athlete(mean=36.60560482218643, variance=5.3867881377156674, position=Position.FORWARD)
# This player is ranked 28
# MONTE CARLO STRAT
# Action: pass, Score: 5.000306818181818
# Action: bid, Score: 5.000035714285715
# Decision: pass
# 2 is deciding whether to pass or bid. Current bid is 2 for Athlete(mean=36.60560482218643, variance=5.3867881377156674, position=Position.FORWARD)
# This player is ranked 28
# PROPORTIONAL STRAT
# Decision: bid
# 4 is deciding whether to pass or bid. Current bid is 3 for Athlete(mean=36.60560482218643, variance=5.3867881377156674, position=Position.FORWARD)
# This player is ranked 28
# FLIP STRAT
# Decision: pass
# 5 is deciding whether to pass or bid. Current bid is 0 for Athlete(mean=40.96059034944464, variance=70.52004598173679, position=Position.GOALIE)
# This player is ranked 9
# PROPORTIONAL STRAT
# Decision: bid
# 0 is deciding whether to pass or bid. Current bid is 0 for Athlete(mean=40.96059034944464, variance=70.52004598173679, position=Position.GOALIE)
# This player is ranked 9
# MONTE CARLO STRAT
# Action: pass, Score: 5.0
# Action: bid, Score: 5.0
# Decision: pass
# 1 is deciding whether to pass or bid. Current bid is 0 for Athlete(mean=40.96059034944464, variance=70.52004598173679, position=Position.GOALIE)
# This player is ranked 9
# FLIP STRAT
# Decision: pass
# 2 is deciding whether to pass or bid. Current bid is 0 for Athlete(mean=40.96059034944464, variance=70.52004598173679, position=Position.GOALIE)
# This player is ranked 9
# PROPORTIONAL STRAT
# Decision: bid
# 3 is deciding whether to pass or bid. Current bid is 1 for Athlete(mean=40.96059034944464, variance=70.52004598173679, position=Position.GOALIE)
# This player is ranked 9
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 4 is deciding whether to pass or bid. Current bid is 1 for Athlete(mean=40.96059034944464, variance=70.52004598173679, position=Position.GOALIE)
# This player is ranked 9
# FLIP STRAT
# Decision: pass
# 5 is deciding whether to pass or bid. Current bid is 0 for Athlete(mean=32.95051676317097, variance=5.2995271713956855, position=Position.FORWARD)
# This player is ranked 30
# PROPORTIONAL STRAT
# Decision: bid
# 0 is deciding whether to pass or bid. Current bid is 0 for Athlete(mean=32.95051676317097, variance=5.2995271713956855, position=Position.FORWARD)
# This player is ranked 30
# MONTE CARLO STRAT
# Action: pass, Score: 5.0
# Action: bid, Score: 5.0
# Decision: pass
# 1 is deciding whether to pass or bid. Current bid is 0 for Athlete(mean=32.95051676317097, variance=5.2995271713956855, position=Position.FORWARD)
# This player is ranked 30
# FLIP STRAT
# Decision: pass
# 2 is deciding whether to pass or bid. Current bid is 0 for Athlete(mean=32.95051676317097, variance=5.2995271713956855, position=Position.FORWARD)
# This player is ranked 30
# PROPORTIONAL STRAT
# Decision: bid
# 3 is deciding whether to pass or bid. Current bid is 1 for Athlete(mean=32.95051676317097, variance=5.2995271713956855, position=Position.FORWARD)
# This player is ranked 30
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 4 is deciding whether to pass or bid. Current bid is 1 for Athlete(mean=32.95051676317097, variance=5.2995271713956855, position=Position.FORWARD)
# This player is ranked 30
# FLIP STRAT
# Decision: pass
# 5 is deciding whether to pass or bid. Current bid is 0 for Athlete(mean=68.8862934142748, variance=6.910330158406515, position=Position.FORWARD)
# This player is ranked 15
# PROPORTIONAL STRAT
# Decision: bid
# 0 is deciding whether to pass or bid. Current bid is 0 for Athlete(mean=68.8862934142748, variance=6.910330158406515, position=Position.FORWARD)
# This player is ranked 15
# MONTE CARLO STRAT
# Action: pass, Score: 5.0
# Action: bid, Score: 5.0
# Decision: pass
# 1 is deciding whether to pass or bid. Current bid is 0 for Athlete(mean=68.8862934142748, variance=6.910330158406515, position=Position.FORWARD)
# This player is ranked 15
# FLIP STRAT
# Decision: pass
# 2 is deciding whether to pass or bid. Current bid is 0 for Athlete(mean=68.8862934142748, variance=6.910330158406515, position=Position.FORWARD)
# This player is ranked 15
# PROPORTIONAL STRAT
# Decision: bid
# 3 is deciding whether to pass or bid. Current bid is 1 for Athlete(mean=68.8862934142748, variance=6.910330158406515, position=Position.FORWARD)
# This player is ranked 15
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 4 is deciding whether to pass or bid. Current bid is 1 for Athlete(mean=68.8862934142748, variance=6.910330158406515, position=Position.FORWARD)
# This player is ranked 15
# FLIP STRAT
# Decision: pass
# 2 is deciding whether to pass or bid. Current bid is 2 for Athlete(mean=68.8862934142748, variance=6.910330158406515, position=Position.FORWARD)
# This player is ranked 15
# PROPORTIONAL STRAT
# Decision: bid
# 4 is deciding whether to pass or bid. Current bid is 3 for Athlete(mean=68.8862934142748, variance=6.910330158406515, position=Position.FORWARD)
# This player is ranked 15
# FLIP STRAT
# Decision: pass
# 2 is deciding whether to pass or bid. Current bid is 4 for Athlete(mean=68.8862934142748, variance=6.910330158406515, position=Position.FORWARD)
# This player is ranked 15
# PROPORTIONAL STRAT
# Decision: bid
# 4 is deciding whether to pass or bid. Current bid is 5 for Athlete(mean=68.8862934142748, variance=6.910330158406515, position=Position.FORWARD)
# This player is ranked 15
# FLIP STRAT
# Decision: pass
# 2 is deciding whether to pass or bid. Current bid is 6 for Athlete(mean=68.8862934142748, variance=6.910330158406515, position=Position.FORWARD)
# This player is ranked 15
# PROPORTIONAL STRAT
# Decision: bid
# 4 is deciding whether to pass or bid. Current bid is 7 for Athlete(mean=68.8862934142748, variance=6.910330158406515, position=Position.FORWARD)
# This player is ranked 15
# FLIP STRAT
# Decision: pass
# 2 is deciding whether to pass or bid. Current bid is 8 for Athlete(mean=68.8862934142748, variance=6.910330158406515, position=Position.FORWARD)
# This player is ranked 15
# PROPORTIONAL STRAT
# Decision: bid
# 4 is deciding whether to pass or bid. Current bid is 9 for Athlete(mean=68.8862934142748, variance=6.910330158406515, position=Position.FORWARD)
# This player is ranked 15
# FLIP STRAT
# Decision: pass
# 2 is deciding whether to pass or bid. Current bid is 10 for Athlete(mean=68.8862934142748, variance=6.910330158406515, position=Position.FORWARD)
# This player is ranked 15
# PROPORTIONAL STRAT
# Decision: bid
# 4 is deciding whether to pass or bid. Current bid is 11 for Athlete(mean=68.8862934142748, variance=6.910330158406515, position=Position.FORWARD)
# This player is ranked 15
# FLIP STRAT
# Decision: pass
# 2 is deciding whether to pass or bid. Current bid is 12 for Athlete(mean=68.8862934142748, variance=6.910330158406515, position=Position.FORWARD)
# This player is ranked 15
# PROPORTIONAL STRAT
# Decision: pass
# 3 is deciding whether to pass or bid. Current bid is 0 for Athlete(mean=28.58283906188312, variance=33.09430567280383, position=Position.GOALIE)
# This player is ranked 12
# VALUE ABOVE REPLACEMENT STRAT
# Decision: pass
# 4 is deciding whether to pass or bid. Current bid is 0 for Athlete(mean=28.58283906188312, variance=33.09430567280383, position=Position.GOALIE)
# This player is ranked 12
# FLIP STRAT
# Decision: pass
# 5 is deciding whether to pass or bid. Current bid is 1 for Athlete(mean=28.58283906188312, variance=33.09430567280383, position=Position.GOALIE)
# This player is ranked 12
# PROPORTIONAL STRAT
# Decision: bid
# 0 is deciding whether to pass or bid. Current bid is 1 for Athlete(mean=28.58283906188312, variance=33.09430567280383, position=Position.GOALIE)
# This player is ranked 12
# MONTE CARLO STRAT
# Action: pass, Score: 5.0
# Action: bid, Score: 5.0
# Decision: pass
# 1 is deciding whether to pass or bid. Current bid is 1 for Athlete(mean=28.58283906188312, variance=33.09430567280383, position=Position.GOALIE)
# This player is ranked 12
# FLIP STRAT
# Decision: pass
# 2 is deciding whether to pass or bid. Current bid is 1 for Athlete(mean=28.58283906188312, variance=33.09430567280383, position=Position.GOALIE)
# This player is ranked 12
# PROPORTIONAL STRAT
# Decision: pass
# 3 is deciding whether to pass or bid. Current bid is 0 for Athlete(mean=47.38299457356655, variance=5.774625687652351, position=Position.FORWARD)
# This player is ranked 21
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 4 is deciding whether to pass or bid. Current bid is 0 for Athlete(mean=47.38299457356655, variance=5.774625687652351, position=Position.FORWARD)
# This player is ranked 21
# FLIP STRAT
# Decision: pass
# 5 is deciding whether to pass or bid. Current bid is 1 for Athlete(mean=47.38299457356655, variance=5.774625687652351, position=Position.FORWARD)
# This player is ranked 21
# PROPORTIONAL STRAT
# Decision: bid
# 0 is deciding whether to pass or bid. Current bid is 1 for Athlete(mean=47.38299457356655, variance=5.774625687652351, position=Position.FORWARD)
# This player is ranked 21
# MONTE CARLO STRAT
# Action: pass, Score: 5.0
# Action: bid, Score: 5.0
# Decision: pass
# 1 is deciding whether to pass or bid. Current bid is 1 for Athlete(mean=47.38299457356655, variance=5.774625687652351, position=Position.FORWARD)
# This player is ranked 21
# FLIP STRAT
# Decision: pass
# 2 is deciding whether to pass or bid. Current bid is 1 for Athlete(mean=47.38299457356655, variance=5.774625687652351, position=Position.FORWARD)
# This player is ranked 21
# PROPORTIONAL STRAT
# Decision: bid
# 4 is deciding whether to pass or bid. Current bid is 2 for Athlete(mean=47.38299457356655, variance=5.774625687652351, position=Position.FORWARD)
# This player is ranked 21
# FLIP STRAT
# Decision: pass
# 2 is deciding whether to pass or bid. Current bid is 3 for Athlete(mean=47.38299457356655, variance=5.774625687652351, position=Position.FORWARD)
# This player is ranked 21
# PROPORTIONAL STRAT
# Decision: bid
# 4 is deciding whether to pass or bid. Current bid is 4 for Athlete(mean=47.38299457356655, variance=5.774625687652351, position=Position.FORWARD)
# This player is ranked 21
# FLIP STRAT
# Decision: bid
# 2 is deciding whether to pass or bid. Current bid is 5 for Athlete(mean=47.38299457356655, variance=5.774625687652351, position=Position.FORWARD)
# This player is ranked 21
# PROPORTIONAL STRAT
# Decision: bid
# 4 is deciding whether to pass or bid. Current bid is 6 for Athlete(mean=47.38299457356655, variance=5.774625687652351, position=Position.FORWARD)
# This player is ranked 21
# FLIP STRAT
# Decision: pass
# 2 is deciding whether to pass or bid. Current bid is 7 for Athlete(mean=47.38299457356655, variance=5.774625687652351, position=Position.FORWARD)
# This player is ranked 21
# PROPORTIONAL STRAT
# Decision: bid
# 4 is deciding whether to pass or bid. Current bid is 8 for Athlete(mean=47.38299457356655, variance=5.774625687652351, position=Position.FORWARD)
# This player is ranked 21
# FLIP STRAT
# Decision: bid
# 2 is deciding whether to pass or bid. Current bid is 9 for Athlete(mean=47.38299457356655, variance=5.774625687652351, position=Position.FORWARD)
# This player is ranked 21
# PROPORTIONAL STRAT
# Decision: bid
# 4 is deciding whether to pass or bid. Current bid is 10 for Athlete(mean=47.38299457356655, variance=5.774625687652351, position=Position.FORWARD)
# This player is ranked 21
# FLIP STRAT
# Decision: pass
# 2 is deciding whether to pass or bid. Current bid is 11 for Athlete(mean=47.38299457356655, variance=5.774625687652351, position=Position.FORWARD)
# This player is ranked 21
# PROPORTIONAL STRAT
# Decision: bid
# 4 is deciding whether to pass or bid. Current bid is 12 for Athlete(mean=47.38299457356655, variance=5.774625687652351, position=Position.FORWARD)
# This player is ranked 21
# FLIP STRAT
# Decision: pass
# 5 is deciding whether to pass or bid. Current bid is 0 for Athlete(mean=30.454770601640604, variance=21.679399222793016, position=Position.GOALIE)
# This player is ranked 10
# PROPORTIONAL STRAT
# Decision: bid
# 0 is deciding whether to pass or bid. Current bid is 0 for Athlete(mean=30.454770601640604, variance=21.679399222793016, position=Position.GOALIE)
# This player is ranked 10
# MONTE CARLO STRAT
# Action: pass, Score: 5.0
# Action: bid, Score: 5.0
# Decision: pass
# 1 is deciding whether to pass or bid. Current bid is 0 for Athlete(mean=30.454770601640604, variance=21.679399222793016, position=Position.GOALIE)
# This player is ranked 10
# FLIP STRAT
# Decision: bid
# 2 is deciding whether to pass or bid. Current bid is 0 for Athlete(mean=30.454770601640604, variance=21.679399222793016, position=Position.GOALIE)
# This player is ranked 10
# PROPORTIONAL STRAT
# Decision: bid
# 3 is deciding whether to pass or bid. Current bid is 0 for Athlete(mean=30.454770601640604, variance=21.679399222793016, position=Position.GOALIE)
# This player is ranked 10
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 4 is deciding whether to pass or bid. Current bid is 0 for Athlete(mean=43.588693254188854, variance=4.525169317428588, position=Position.FORWARD)
# This player is ranked 23
# FLIP STRAT
# Decision: pass
# 5 is deciding whether to pass or bid. Current bid is 0 for Athlete(mean=43.588693254188854, variance=4.525169317428588, position=Position.FORWARD)
# This player is ranked 23
# PROPORTIONAL STRAT
# Decision: bid
# 0 is deciding whether to pass or bid. Current bid is 0 for Athlete(mean=43.588693254188854, variance=4.525169317428588, position=Position.FORWARD)
# This player is ranked 23
# MONTE CARLO STRAT
# Action: pass, Score: 5.0
# Action: bid, Score: 5.0
# Decision: pass
# 1 is deciding whether to pass or bid. Current bid is 0 for Athlete(mean=43.588693254188854, variance=4.525169317428588, position=Position.FORWARD)
# This player is ranked 23
# FLIP STRAT
# Decision: pass
# 2 is deciding whether to pass or bid. Current bid is 0 for Athlete(mean=43.588693254188854, variance=4.525169317428588, position=Position.FORWARD)
# This player is ranked 23
# PROPORTIONAL STRAT
# Decision: bid
# 3 is deciding whether to pass or bid. Current bid is 0 for Athlete(mean=26.283678997827238, variance=2.774836760505577, position=Position.FORWARD)
# This player is ranked 35
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 4 is deciding whether to pass or bid. Current bid is 0 for Athlete(mean=26.283678997827238, variance=2.774836760505577, position=Position.FORWARD)
# This player is ranked 35
# FLIP STRAT
# Decision: pass
# 5 is deciding whether to pass or bid. Current bid is 0 for Athlete(mean=26.283678997827238, variance=2.774836760505577, position=Position.FORWARD)
# This player is ranked 35
# PROPORTIONAL STRAT
# Decision: bid
# 0 is deciding whether to pass or bid. Current bid is 0 for Athlete(mean=26.283678997827238, variance=2.774836760505577, position=Position.FORWARD)
# This player is ranked 35
# MONTE CARLO STRAT
# Action: pass, Score: 5.0
# Action: bid, Score: 5.0
# Decision: pass
# 1 is deciding whether to pass or bid. Current bid is 0 for Athlete(mean=26.283678997827238, variance=2.774836760505577, position=Position.FORWARD)
# This player is ranked 35
# FLIP STRAT
# Decision: bid
# 2 is deciding whether to pass or bid. Current bid is 0 for Athlete(mean=16.214818751513295, variance=1.7146787720277796, position=Position.FORWARD)
# This player is ranked 41
# PROPORTIONAL STRAT
# Decision: bid
# 3 is deciding whether to pass or bid. Current bid is 0 for Athlete(mean=16.214818751513295, variance=1.7146787720277796, position=Position.FORWARD)
# This player is ranked 41
# VALUE ABOVE REPLACEMENT STRAT
# Decision: bid
# 4 is deciding whether to pass or bid. Current bid is 0 for Athlete(mean=16.214818751513295, variance=1.7146787720277796, position=Position.FORWARD)
# This player is ranked 41
# FLIP STRAT
# Decision: pass
# 5 is deciding whether to pass or bid. Current bid is 0 for Athlete(mean=16.214818751513295, variance=1.7146787720277796, position=Position.FORWARD)
# This player is ranked 41
# PROPORTIONAL STRAT
# Decision: bid
# 0 is deciding whether to pass or bid. Current bid is 0 for Athlete(mean=16.214818751513295, variance=1.7146787720277796, position=Position.FORWARD)
# This player is ranked 41
# MONTE CARLO STRAT
# Action: pass, Score: 5.0
# Action: bid, Score: 5.0
# Decision: pass

# %%
specified = ['monte_carlo', 'flip', 'proportional', 'value_above_replacement', 'monte_carlo', 'monte_carlo']
run_and_display_auction('../test_outputs/output2.txt', specified)
